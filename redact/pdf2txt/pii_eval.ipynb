# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import glob
import numpy as np
import pandas as pd

# %%
master_labels_fn = '../data/data_generation/master_label.csv'

# Read master labels
master_labels = pd.read_csv(master_labels_fn)
print("Master Labels:")
print(master_labels)
print("\n" + "="*80 + "\n")

# Columns to check (excluding file_name and template_id)
columns_to_check = ['full_name', 'company_name', 'company_address', 'phone_number']


json_pii_folder='../data/json_pii/'
fns = glob.glob(f'{json_pii_folder}*.json')
fns = sorted([fn.split('/')[-1] for fn in fns if 'paddle' in fn ])

import json

# Initialize stats tracking
total_comparisons = 0
total_matches = 0
column_stats = {col: {'matches': 0, 'total': 0} for col in columns_to_check}
file_stats = []

print(f"Found {len(fns)} JSON files to process\n")

for fn in fns:
    json_path = os.path.join(json_pii_folder, fn)
    with open(json_path, 'r') as f:
        json_data = json.load(f)
    
    # Try different filename patterns
    lookup_name = fn.replace('tesseract_','').replace('paddle_','').replace('.json','')
    print(f"Looking for '{lookup_name}' in master_labels...")
    
    # Find corresponding row in master_labels
    row = master_labels[master_labels['file_name'] == lookup_name]
    if row.empty:
        print(f"  ❌ No matching row for {fn} (tried: {lookup_name})")
        print(f"  Available filenames in master_labels: {master_labels['file_name'].tolist()[:5]}...")
        continue
    
    row = row.iloc[0]
    print(f"  ✓ Found match!")
    print(f"\nComparing {fn}:")
    
    file_matches = 0
    file_total = 0
    
    for col in columns_to_check:
        json_val = json_data.get(col, None)
        csv_val = row[col]
        match = json_val == csv_val
        print(f"  {col}: JSON='{json_val}' | CSV='{csv_val}' | Match={match}")
        
        # Update stats
        total_comparisons += 1
        file_total += 1
        column_stats[col]['total'] += 1
        
        if match:
            total_matches += 1
            file_matches += 1
            column_stats[col]['matches'] += 1
    
    file_accuracy = (file_matches / file_total * 100) if file_total > 0 else 0
    file_stats.append({'file': fn, 'matches': file_matches, 'total': file_total, 'accuracy': file_accuracy})
    print(f"  File Accuracy: {file_matches}/{file_total} ({file_accuracy:.2f}%)")
    print("-"*40)

# Print overall statistics
print("\n" + "="*80)
print("OVERALL STATISTICS")
print("="*80)

if total_comparisons == 0:
    print("\n⚠️  WARNING: No files were successfully compared!")
    print("Check that the filenames in JSON folder match those in master_labels.csv")
else:
    overall_accuracy = (total_matches / total_comparisons * 100) if total_comparisons > 0 else 0
    print(f"\nOverall Accuracy: {total_matches}/{total_comparisons} ({overall_accuracy:.2f}%)")

    print("\n" + "-"*40)
    print("Per-Column Accuracy:")
    print("-"*40)
    for col in columns_to_check:
        matches = column_stats[col]['matches']
        total = column_stats[col]['total']
        accuracy = (matches / total * 100) if total > 0 else 0
        print(f"  {col:20s}: {matches:3d}/{total:3d} ({accuracy:6.2f}%)")

    print("\n" + "-"*40)
    print("Per-File Accuracy:")
    print("-"*40)
    for stat in file_stats:
        print(f"  {stat['file']:40s}: {stat['matches']}/{stat['total']} ({stat['accuracy']:6.2f}%)")

    # Create summary DataFrame
    if len(file_stats) > 0:
        summary_df = pd.DataFrame(file_stats)
        print("\n" + "="*80)
        print("Summary Statistics:")
        print(f"  Mean Accuracy: {summary_df['accuracy'].mean():.2f}%")
        print(f"  Median Accuracy: {summary_df['accuracy'].median():.2f}%")
        print(f"  Min Accuracy: {summary_df['accuracy'].min():.2f}%")
        print(f"  Max Accuracy: {summary_df['accuracy'].max():.2f}%")
        print(f"  Std Dev: {summary_df['accuracy'].std():.2f}%")
# Out:
# Master Labels:
#                file_name  full_name    company_name  \
# 0   Redactor_sample_0001   ソフィア・ミラー   株式会社オリオンシステムズ
# 1   Redactor_sample_0002   キム・ミンジュン      ネクサス貿易合同会社
# 2   Redactor_sample_0003  エミリー・ブラウン  スカイネット・ロジスティクス
# 3   Redactor_sample_0004    チャン・ウェイ   株式会社アース・クリエイト
# 4   Redactor_sample_0005   ルイス・カルロス   株式会社オリオンシステムズ
# ..                   ...        ...             ...
# 59  Redactor_sample_0060      野村 美穂        リバーサイド工業
# 60  Redactor_sample_0061      古川 幸助    株式会社アルファドライブ
# 61  Redactor_sample_0062       菊地 栞       合同会社サンセット
# 62  Redactor_sample_0063      千葉 雄大    株式会社アルファドライブ
# 63  Redactor_sample_0064      上野 莉奈       合同会社サンセット
#
#                                company_address  phone_number  template_id
# 0      〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ  03-6262-1212            1
# 1   〒220-0012 神奈川県横浜市西区みなとみらい2-2-1 横浜ランドマークタワー  045-222-5501            1
# 2           〒530-0011 大阪府大阪市北区大深町3-1 グランフロント大阪  06-6372-6789            1
# 3         〒812-0012 福岡県福岡市博多区博多駅中央街1-1 JR博多シティ  092-475-8000            1
# 4      〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ  03-6262-1213            1
# ..                                         ...           ...          ...
# 59    〒950-0088 新潟県新潟市中央区万代1-6-1 万代シテイバスセンタービル  025-246-6112            4
# 60              〒108-0073 東京都港区三田1-4-28 三田国際ビル  03-3452-1111            4
# 61            〒900-0015 沖縄県那覇市久茂地1-1-1 パレットくもじ  098-867-1171            4
# 62              〒108-0073 東京都港区三田1-4-28 三田国際ビル  03-3452-1113            4
# 63            〒900-0015 沖縄県那覇市久茂地1-1-1 パレットくもじ  098-867-1172            4
#
# [64 rows x 6 columns]
#
# ================================================================================
#
# Found 64 JSON files to process
#
# Looking for 'Redactor_sample_0001' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0001.json:
#   full_name: JSON='ソフィア・ミラー' | CSV='ソフィア・ミラー' | Match=True
#   company_name: JSON='株式会社オリオンシステムズ' | CSV='株式会社オリオンシステムズ' | Match=True
#   company_address: JSON='None' | CSV='〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ' | Match=False
#   phone_number: JSON='03-6262-1212' | CSV='03-6262-1212' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0002' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0002.json:
#   full_name: JSON='キム・ミンジュン' | CSV='キム・ミンジュン' | Match=True
#   company_name: JSON='ネクサス貿易合同会社会社' | CSV='ネクサス貿易合同会社' | Match=False
#   company_address: JSON='None' | CSV='〒220-0012 神奈川県横浜市西区みなとみらい2-2-1 横浜ランドマークタワー' | Match=False
#   phone_number: JSON='045-222-5501' | CSV='045-222-5501' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0003' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0003.json:
#   full_name: JSON='エミリー・ブラウン' | CSV='エミリー・ブラウン' | Match=True
#   company_name: JSON='スカイネット・ロジスティクス' | CSV='スカイネット・ロジスティクス' | Match=True
#   company_address: JSON='None' | CSV='〒530-0011 大阪府大阪市北区大深町3-1 グランフロント大阪' | Match=False
#   phone_number: JSON='06-6372-6789' | CSV='06-6372-6789' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0004' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0004.json:
#   full_name: JSON='渡辺ジョン' | CSV='チャン・ウェイ' | Match=False
#   company_name: JSON='なんかんかな株式会社' | CSV='株式会社アース・クリエイト' | Match=False
#   company_address: JSON='None' | CSV='〒812-0012 福岡県福岡市博多区博多駅中央街1-1 JR博多シティ' | Match=False
#   phone_number: JSON='092-475-8000' | CSV='092-475-8000' | Match=True
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0005' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0005.json:
#   full_name: JSON='ルイス・カルロス' | CSV='ルイス・カルロス' | Match=True
#   company_name: JSON='株式会社オリオンシステムズ' | CSV='株式会社オリオンシステムズ' | Match=True
#   company_address: JSON='None' | CSV='〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ' | Match=False
#   phone_number: JSON='03-6262-1213' | CSV='03-6262-1213' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0006' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0006.json:
#   full_name: JSON='アナ・ペレイラ' | CSV='アナ・ペレイラ' | Match=True
#   company_name: JSON='Nexus Trade Co., Ltd.' | CSV='ネクサス貿易合同会社' | Match=False
#   company_address: JSON='None' | CSV='〒220-0012 神奈川県横浜市西区みなとみらい2-2-1 横浜ランドマークタワー' | Match=False
#   phone_number: JSON='045-222-5502' | CSV='045-222-5502' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0007' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0007.json:
#   full_name: JSON='ダニエル・リベラ' | CSV='ダニエル・リベラ' | Match=True
#   company_name: JSON='スカイネット・ロジスティクス' | CSV='スカイネット・ロジスティクス' | Match=True
#   company_address: JSON='None' | CSV='〒530-0011 大阪府大阪市北区大深町3-1 グランフロント大阪' | Match=False
#   phone_number: JSON='06-6372-6790' | CSV='06-6372-6790' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0008' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0008.json:
#   full_name: JSON='イワン・ポポフ' | CSV='イワン・ポポフ' | Match=True
#   company_name: JSON='株式会社アース・クリエイト' | CSV='株式会社アース・クリエイト' | Match=True
#   company_address: JSON='None' | CSV='〒812-0012 福岡県福岡市博多区博多駅中央街1-1 JR博多シティ' | Match=False
#   phone_number: JSON='092-475-8001' | CSV='092-475-8001' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0009' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0009.json:
#   full_name: JSON='オリビア・マーティン' | CSV='オリビア・マーティン' | Match=True
#   company_name: JSON='ホライズン・コンサルティング' | CSV='ホライズン・コンサルティング' | Match=True
#   company_address: JSON='None' | CSV='〒106-6150 東京都港区六本木6-10-1 六本木ヒルズ森タワー' | Match=False
#   phone_number: JSON='03-6406-6000' | CSV='03-6406-6000' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0010' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0010.json:
#   full_name: JSON='ファティマ・アリ' | CSV='ファティマ・アリ' | Match=True
#   company_name: JSON='ファティマ・アリ会社' | CSV='パシフィック・ゲートウェイ' | Match=False
#   company_address: JSON='None' | CSV='〒650-0044 兵庫県神戸市中央区東川崎町1-6-1 神戸ハーバーランドumie' | Match=False
#   phone_number: JSON='078-382-7100' | CSV='078-382-7100' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0011' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0011.json:
#   full_name: JSON='アレクサンダー・シュミット' | CSV='アレクサンダー・シュミット' | Match=True
#   company_name: JSON='ホライズン・コンサルティング' | CSV='ホライズン・コンサルティング' | Match=True
#   company_address: JSON='None' | CSV='〒106-6150 東京都港区六本木6-10-1 六本木ヒルズ森タワー' | Match=False
#   phone_number: JSON='03-6406-6001' | CSV='03-6406-6001' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0012' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0012.json:
#   full_name: JSON='マリア・ゴンザレス' | CSV='マリア・ゴンザレス' | Match=True
#   company_name: JSON='パシフィック・ゲートウェイ' | CSV='パシフィック・ゲートウェイ' | Match=True
#   company_address: JSON='None' | CSV='〒650-0044 兵庫県神戸市中央区東川崎町1-6-1 神戸ハーバーランドumie' | Match=False
#   phone_number: JSON='078-382-7101' | CSV='078-382-7101' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0013' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0013.json:
#   full_name: JSON='ムハンマド・イクバル' | CSV='ムハンマド・イクバル' | Match=True
#   company_name: JSON='株式会社コスモ企画会社' | CSV='株式会社コスモ企画' | Match=False
#   company_address: JSON='None' | CSV='〒160-0023 東京都新宿区西新宿6-5-1 新宿アイランドタワー' | Match=False
#   phone_number: JSON='03-3348-1111' | CSV='03-3348-1111' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0014' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0014.json:
#   full_name: JSON='クロエ・ルコント' | CSV='クロエ・ルコント' | Match=True
#   company_name: JSON='アクアソリューションズ合同会社会' | CSV='アクアソリューションズ合同会社' | Match=False
#   company_address: JSON='None' | CSV='〒450-6201 愛知県名古屋市中村区名駅4-7-1 ミッドランドスクエア' | Match=False
#   phone_number: JSON='052-527-8888' | CSV='052-527-8888' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0015' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0015.json:
#   full_name: JSON='ラファエル・フェルナンデス' | CSV='ラファエル・フェルナンデス' | Match=True
#   company_name: JSON='コスモ企画' | CSV='株式会社コスモ企画' | Match=False
#   company_address: JSON='None' | CSV='〒160-0023 東京都新宿区西新宿6-5-1 新宿アイランドタワー' | Match=False
#   phone_number: JSON='03-3348-1112' | CSV='03-3348-1112' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0016' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0016.json:
#   full_name: JSON='ユリア・ノビコワ' | CSV='ユリア・ノビコワ' | Match=True
#   company_name: JSON='アクアソリューションズ合同会社会社' | CSV='アクアソリューションズ合同会社' | Match=False
#   company_address: JSON='None' | CSV='〒450-6201 愛知県名古屋市中村区名駅4-7-1 ミッドランドスクエア' | Match=False
#   phone_number: JSON='052-527-8889' | CSV='052-527-8889' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0017' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0017.json:
#   full_name: JSON='佐々木翔太' | CSV='佐々木 翔太' | Match=False
#   company_name: JSON='日の出製作所' | CSV='日の出製作所' | Match=True
#   company_address: JSON='None' | CSV='〒131-8634 東京都墨田区押上1-1-2 東京スカイツリーイーストタワー' | Match=False
#   phone_number: JSON='03-5809-5050' | CSV='03-5809-5050' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0018' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0018.json:
#   full_name: JSON='山田優子' | CSV='山田 優子' | Match=False
#   company_name: JSON='株式会社ミナト電機' | CSV='株式会社ミナト電機' | Match=True
#   company_address: JSON='None' | CSV='〒231-0001 神奈川県横浜市中区新港1-3-1 横浜赤レンガ倉庫' | Match=False
#   phone_number: JSON='045-211-1555' | CSV='045-211-1555' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0019' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0019.json:
#   full_name: JSON='木下拓海' | CSV='木下 拓海' | Match=False
#   company_name: JSON='関西スチール' | CSV='関西スチール株式会社' | Match=False
#   company_address: JSON='None' | CSV='〒542-0076 大阪府大阪市中央区難波5-1-60 なんばパークス' | Match=False
#   phone_number: JSON='06-6644-7100' | CSV='06-6644-7100' | Match=True
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0020' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0020.json:
#   full_name: JSON='森りん' | CSV='森 りん' | Match=False
#   company_name: JSON='中部ファィンテック' | CSV='中部ファインテック' | Match=False
#   company_address: JSON='None' | CSV='〒460-0008 愛知県名古屋市中区栄3-5-1 名古屋三越' | Match=False
#   phone_number: JSON='04-1234-5678' | CSV='052-252-1111' | Match=False
#   File Accuracy: 0/4 (0.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0021' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0021.json:
#   full_name: JSON='池田 蓮' | CSV='池田 蓮' | Match=True
#   company_name: JSON='日出製作所' | CSV='日の出製作所' | Match=False
#   company_address: JSON='None' | CSV='〒131-8634 東京都墨田区押上1-1-2 東京スカイツリーイーストタワー' | Match=False
#   phone_number: JSON='03-5809-5051' | CSV='03-5809-5051' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0022' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0022.json:
#   full_name: JSON='橋本 あかり' | CSV='橋本 あかり' | Match=True
#   company_name: JSON='株式会社ミナト電機' | CSV='株式会社ミナト電機' | Match=True
#   company_address: JSON='None' | CSV='〒231-0001 神奈川県横浜市中区新港1-3-1 横浜赤レンガ倉庫' | Match=False
#   phone_number: JSON='045-211-1556' | CSV='045-211-1556' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0023' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0023.json:
#   full_name: JSON='石川 大地' | CSV='石川 大地' | Match=True
#   company_name: JSON='関西スチール' | CSV='関西スチール株式会社' | Match=False
#   company_address: JSON='None' | CSV='〒542-0076 大阪府大阪市中央区難波5-1-60 なんばパークス' | Match=False
#   phone_number: JSON='06-6644-7102' | CSV='06-6644-7102' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0024' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0024.json:
#   full_name: JSON='清水 結衣' | CSV='清水 結衣' | Match=True
#   company_name: JSON='中部ファインテック' | CSV='中部ファインテック' | Match=True
#   company_address: JSON='None' | CSV='〒460-0008 愛知県名古屋市中区栄3-5-1 名古屋三越' | Match=False
#   phone_number: JSON='052-252-1113' | CSV='052-252-1113' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0025' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0025.json:
#   full_name: JSON='前田 悠斗' | CSV='前田 悠斗' | Match=True
#   company_name: JSON='株式会社サンライズ物流会社' | CSV='株式会社サンライズ物流' | Match=False
#   company_address: JSON='None' | CSV='〒135-8625 東京都江東区豊洲2-4-9 アーバンドック ららぽーと豊洲' | Match=False
#   phone_number: JSON='03-6910-1234' | CSV='03-6910-1234' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0026' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0026.json:
#   full_name: JSON='藤井 菜々' | CSV='藤井 菜々' | Match=True
#   company_name: JSON='サクラ精密機器会社' | CSV='サクラ精密機器' | Match=False
#   company_address: JSON='None' | CSV='〒330-9555 埼玉県さいたま市大宮区桜木町1-7-5 ソニックシティビル' | Match=False
#   phone_number: JSON='048-647-4111' | CSV='048-647-4111' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0027' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0027.json:
#   full_name: JSON='岡田 航' | CSV='岡田 航' | Match=True
#   company_name: JSON='株式会社サンライズ物流会社' | CSV='株式会社サンライズ物流' | Match=False
#   company_address: JSON='None' | CSV='〒135-8625 東京都江東区豊洲2-4-9 アーバンドック ららぽーと豊洲' | Match=False
#   phone_number: JSON='03-6910-1235' | CSV='03-6910-1235' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0028' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0028.json:
#   full_name: JSON='後藤 美月' | CSV='後藤 美月' | Match=True
#   company_name: JSON='サクラ精密機器会社' | CSV='サクラ精密機器' | Match=False
#   company_address: JSON='None' | CSV='〒330-9555 埼玉県さいたま市大宮区桜木町1-7-5 ソニックシティビル' | Match=False
#   phone_number: JSON='048-647-4112' | CSV='048-647-4112' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0029' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0029.json:
#   full_name: JSON='村上 楓太' | CSV='村上 颯太' | Match=False
#   company_name: JSON='フロンティアージェンシー' | CSV='フロンティア・エージェンシー' | Match=False
#   company_address: JSON='None' | CSV='〒150-0002 東京都渋谷区渋谷2-24-12 渋谷スクランブルスクエア' | Match=False
#   phone_number: JSON='03-4221-4280' | CSV='03-4221-4280' | Match=True
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0030' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0030.json:
#   full_name: JSON='長谷川 勒子' | CSV='長谷川 莉子' | Match=False
#   company_name: JSON='京葉エンジニアリング会社' | CSV='株式会社京葉エンジニアリング' | Match=False
#   company_address: JSON='None' | CSV='〒261-7132 千葉県千葉市美浜区中瀬2-6-1 WBGマリブウエスト' | Match=False
#   phone_number: JSON='043-297-300℃' | CSV='043-297-3000' | Match=False
#   File Accuracy: 0/4 (0.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0031' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0031.json:
#   full_name: JSON='西村 陽菜' | CSV='西村 陽菜' | Match=True
#   company_name: JSON='フロンティア・ージェンシー' | CSV='フロンティア・エージェンシー' | Match=False
#   company_address: JSON='None' | CSV='〒150-0002 東京都渋谷区渋谷2-24-12 渋谷スクランブルスクエア' | Match=False
#   phone_number: JSON='03-4221-4281' | CSV='03-4221-4281' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0032' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0032.json:
#   full_name: JSON='石井 涼介' | CSV='石井 涼介' | Match=True
#   company_name: JSON='京葉エンジニアリング株式会社' | CSV='株式会社京葉エンジニアリング' | Match=False
#   company_address: JSON='None' | CSV='〒261-7132 千葉県千葉市美浜区中瀬2-6-1 WBGマリブウエスト' | Match=False
#   phone_number: JSON='043-297-3001' | CSV='043-297-3001' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0033' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0033.json:
#   full_name: JSON='山口 智也' | CSV='山口 智也' | Match=True
#   company_name: JSON='株式会社デジタル・ウェイブ' | CSV='株式会社デジタル・ウェイブ' | Match=True
#   company_address: JSON='None' | CSV='〒105-7333 東京都港区東新橋1-9-1 東京汐留ビルディング' | Match=False
#   phone_number: JSON='不明（契約期間内は電話番号が記載されていない）' | CSV='03-6252-3456' | Match=False
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0034' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0034.json:
#   full_name: JSON='宮崎 楓' | CSV='宮崎 楓' | Match=True
#   company_name: JSON='アーバンリサーチ株式会社会社' | CSV='アーバンリサーチ株式会社' | Match=False
#   company_address: JSON='None' | CSV='〒550-0015 大阪府大阪市西区南堀江1-14-26 中澤唐木ビル' | Match=False
#   phone_number: JSON='04-1234-5678' | CSV='06-6536-2323' | Match=False
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0035' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0035.json:
#   full_name: JSON='野口 和樹' | CSV='野口 和樹' | Match=True
#   company_name: JSON='株式会社アイリス' | CSV='株式会社アイリス' | Match=True
#   company_address: JSON='None' | CSV='〒980-0021 宮城県仙台市青葉区中央1-2-3 仙台マークワン' | Match=False
#   phone_number: JSON='022-716-1111' | CSV='022-716-1111' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0036' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0036.json:
#   full_name: JSON='大塚 さくら' | CSV='大塚 さくら' | Match=True
#   company_name: JSON='ネオ・コーポレーション' | CSV='株式会社ネオ・コーポレーション' | Match=False
#   company_address: JSON='None' | CSV='〒060-0005 北海道札幌市中央区北5条西2-5 JRタワー' | Match=False
#   phone_number: JSON='011-209-5100' | CSV='011-209-5100' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0037' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0037.json:
#   full_name: JSON='松田 竜也' | CSV='松田 竜也' | Match=True
#   company_name: JSON='株式会社デジタル・ウェイブ' | CSV='株式会社デジタル・ウェイブ' | Match=True
#   company_address: JSON='None' | CSV='〒105-7333 東京都港区東新橋1-9-1 東京汐留ビルディング' | Match=False
#   phone_number: JSON='03-6252-3457' | CSV='03-6252-3457' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0038' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0038.json:
#   full_name: JSON='小野恵子' | CSV='小野 恵子' | Match=False
#   company_name: JSON='アーバンリサーチ株式会社' | CSV='アーバンリサーチ株式会社' | Match=True
#   company_address: JSON='None' | CSV='〒550-0015 大阪府大阪市西区南堀江1-14-26 中澤唐木ビル' | Match=False
#   phone_number: JSON='06-6536-2324' | CSV='06-6536-2324' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0039' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0039.json:
#   full_name: JSON='田村亮' | CSV='田村 亮' | Match=False
#   company_name: JSON='株式会社アイリス' | CSV='株式会社アイリス' | Match=True
#   company_address: JSON='None' | CSV='〒980-0021 宮城県仙台市青葉区中央1-2-3 仙台マークワン' | Match=False
#   phone_number: JSON='022-716-1112' | CSV='022-716-1112' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0040' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0040.json:
#   full_name: JSON='杉山 結菜' | CSV='杉山 結菜' | Match=True
#   company_name: JSON='ネオ・コーポレーション' | CSV='株式会社ネオ・コーポレーション' | Match=False
#   company_address: JSON='None' | CSV='〒060-0005 北海道札幌市中央区北5条西2-5 JRタワー' | Match=False
#   phone_number: JSON='011-209-5101' | CSV='011-209-5101' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0041' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0041.json:
#   full_name: JSON='工藤浩二' | CSV='工藤 浩二' | Match=False
#   company_name: JSON='株式会社クリエイティブギア' | CSV='株式会社クリエイティブギア' | Match=True
#   company_address: JSON='None' | CSV='〒104-0061 東京都中央区銀座6-10-1 GINZA SIX' | Match=False
#   phone_number: JSON='03-6891-3333' | CSV='03-6891-3333' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0042' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0042.json:
#   full_name: JSON='鎌田美優' | CSV='鎌田 美優' | Match=False
#   company_name: JSON='アスカプランニング' | CSV='合同会社アスカプランニング' | Match=False
#   company_address: JSON='None' | CSV='〒600-8555 京都府京都市下京区烏丸通塩小路下る東塩小路町 ジェイアール京都伊勢丹' | Match=False
#   phone_number: JSON='075-352-1111' | CSV='075-352-1111' | Match=True
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0043' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0043.json:
#   full_name: JSON='岩崎健' | CSV='岩崎 健' | Match=False
#   company_name: JSON='株式会社クリエイティブギア' | CSV='株式会社クリエイティブギア' | Match=True
#   company_address: JSON='None' | CSV='〒104-0061 東京都中央区銀座6-10-1 GINZA SIX' | Match=False
#   phone_number: JSON='04-1234-5678' | CSV='03-6891-3334' | Match=False
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0044' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0044.json:
#   full_name: JSON='中野 あおい' | CSV='中野 あおい' | Match=True
#   company_name: JSON='アスカプランニング' | CSV='合同会社アスカプランニング' | Match=False
#   company_address: JSON='None' | CSV='〒600-8555 京都府京都市下京区烏丸通塩小路下る東塩小路町 ジェイアール京都伊勢丹' | Match=False
#   phone_number: JSON='075-352-1112' | CSV='075-352-1112' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0045' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0045.json:
#   full_name: JSON='福田 隼人' | CSV='福田 隼人' | Match=True
#   company_name: JSON='オーシャン・キャピタル・パートナーズ' | CSV='オーシャン・キャピタル・パートナーズ' | Match=True
#   company_address: JSON='None' | CSV='〒100-6990 東京都千代田区丸の内2-6-1 丸の内ブリックスクエア' | Match=False
#   phone_number: JSON='03-3211-8800' | CSV='03-3211-8800' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0046' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0046.json:
#   full_name: JSON='三浦 琴音' | CSV='三浦 琴音' | Match=True
#   company_name: JSON='株式会社ウエストサイド' | CSV='株式会社ウエストサイド' | Match=True
#   company_address: JSON='None' | CSV='〒730-0035 広島県広島市中区本通10-1 広島パルコ' | Match=False
#   phone_number: JSON='082-542-2111' | CSV='082-542-2111' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0047' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0047.json:
#   full_name: JSON='竹内 樹' | CSV='竹内 樹' | Match=True
#   company_name: JSON='オーシャン・キャピタル・パートナーズ' | CSV='オーシャン・キャピタル・パートナーズ' | Match=True
#   company_address: JSON='None' | CSV='〒100-6990 東京都千代田区丸の内2-6-1 丸の内ブリックスクエア' | Match=False
#   phone_number: JSON='03-3211-8801' | CSV='03-3211-8801' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0048' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0048.json:
#   full_name: JSON='安藤 梨花' | CSV='安藤 梨花' | Match=True
#   company_name: JSON='株式会社ウエストサイド' | CSV='株式会社ウエストサイド' | Match=True
#   company_address: JSON='None' | CSV='〒730-0035 広島県広島市中区本通10-1 広島パルコ' | Match=False
#   phone_number: JSON='330,000円' | CSV='082-542-2112' | Match=False
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0049' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0049.json:
#   full_name: JSON='中島 悠' | CSV='中島 悠' | Match=True
#   company_name: JSON='株式会社ブレインワークス' | CSV='株式会社ブレインワークス' | Match=True
#   company_address: JSON='None' | CSV='〒153-0051 東京都目黒区上目黒1-26-1 中目黒アトラスタワー' | Match=False
#   phone_number: JSON='03-5725-7777' | CSV='03-5725-7777' | Match=True
#   File Accuracy: 3/4 (75.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0050' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0050.json:
#   full_name: JSON='今井 詩織' | CSV='今井 詩織' | Match=True
#   company_name: JSON='富士テクノサービス' | CSV='富士テクノサービス株式会社' | Match=False
#   company_address: JSON='None' | CSV='〒420-8508 静岡県静岡市葵区追手町9-6 静岡県庁' | Match=False
#   phone_number: JSON='静岡県庁電話番号054-221-2121' | CSV='054-221-2121' | Match=False
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0051' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0051.json:
#   full_name: JSON='浜田 隆' | CSV='浜田 陸' | Match=False
#   company_name: JSON='浜田隆株式会社ノーススター' | CSV='株式会社ノーススター' | Match=False
#   company_address: JSON='None' | CSV='〒064-0804 北海道札幌市中央区南4条西4-1 札幌ステラプレイス' | Match=False
#   phone_number: JSON='011-209-5000' | CSV='011-209-5000' | Match=True
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0052' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0052.json:
#   full_name: JSON='藤本千夏' | CSV='藤本 千夏' | Match=False
#   company_name: JSON='九州イノベーションズ株式会社' | CSV='九州イノベーションズ' | Match=False
#   company_address: JSON='None' | CSV='〒810-8680 福岡県福岡市中央区天神1-4-1 大丸福岡天神店' | Match=False
#   phone_number: JSON='092-712-8181' | CSV='092-712-8181' | Match=True
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0053' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0053.json:
#   full_name: JSON='原田拓也' | CSV='原田 拓也' | Match=False
#   company_name: JSON='株式会社ブレインワークス' | CSV='株式会社ブレインワークス' | Match=True
#   company_address: JSON='None' | CSV='〒153-0051 東京都目黒区上目黒1-26-1 中目黒アトラスタワー' | Match=False
#   phone_number: JSON='03-5725-7778' | CSV='03-5725-7778' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0054' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0054.json:
#   full_name: JSON='小川真奈' | CSV='小川 真奈' | Match=False
#   company_name: JSON='富士テクノサービス' | CSV='富士テクノサービス株式会社' | Match=False
#   company_address: JSON='None' | CSV='〒420-8508 静岡県静岡市葵区追手町9-6 静岡県庁' | Match=False
#   phone_number: JSON='静岡県庁電話番号054-221-2122' | CSV='054-221-2122' | Match=False
#   File Accuracy: 0/4 (0.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0055' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0055.json:
#   full_name: JSON='田田 彰' | CSV='太田 彰' | Match=False
#   company_name: JSON='太田 彰 株式会社ノーススター' | CSV='株式会社ノーススター' | Match=False
#   company_address: JSON='None' | CSV='〒064-0804 北海道札幌市中央区南4条西4-1 札幌ステラプレイス' | Match=False
#   phone_number: JSON='011-209-5001' | CSV='011-209-5001' | Match=True
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0056' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0056.json:
#   full_name: JSON='内田 めい' | CSV='内田 芽衣' | Match=False
#   company_name: JSON='九州イノベーションズ' | CSV='九州イノベーションズ' | Match=True
#   company_address: JSON='None' | CSV='〒810-8680 福岡県福岡市中央区天神1-4-1 大丸福岡天神店' | Match=False
#   phone_number: JSON='092-712-8182' | CSV='092-712-8182' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0057' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0057.json:
#   full_name: JSON='篠原健一' | CSV='篠原 健一' | Match=False
#   company_name: JSON='株式会社スマートリンク' | CSV='株式会社スマートリンク' | Match=True
#   company_address: JSON='None' | CSV='〒180-0004 東京都武蔵野市吉祥寺本町1-11-5 コピス吉祥寺' | Match=False
#   phone_number: JSON='180-0004-01-11' | CSV='0422-27-2100' | Match=False
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0058' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0058.json:
#   full_name: JSON='吉川ほのか' | CSV='吉川 ほのか' | Match=False
#   company_name: JSON='リバーサイド工業' | CSV='リバーサイド工業' | Match=True
#   company_address: JSON='None' | CSV='〒950-0088 新潟県新潟市中央区万代1-6-1 万代シテイバスセンタービル' | Match=False
#   phone_number: JSON='04-1234-5678' | CSV='025-246-6111' | Match=False
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0059' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0059.json:
#   full_name: JSON='小島 昇' | CSV='小島 昇' | Match=True
#   company_name: JSON='株式会社 スマートリンク 会社名' | CSV='株式会社スマートリンク' | Match=False
#   company_address: JSON='None' | CSV='〒180-0004 東京都武蔵野市吉祥寺本町1-11-5 コピス吉祥寺' | Match=False
#   phone_number: JSON='0422-27-2101' | CSV='0422-27-2101' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0060' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0060.json:
#   full_name: JSON='野村美穂' | CSV='野村 美穂' | Match=False
#   company_name: JSON='リバーサイド工業' | CSV='リバーサイド工業' | Match=True
#   company_address: JSON='None' | CSV='〒950-0088 新潟県新潟市中央区万代1-6-1 万代シテイバスセンタービル' | Match=False
#   phone_number: JSON='未指定（契約書に記載なし）' | CSV='025-246-6112' | Match=False
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0061' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0061.json:
#   full_name: JSON='古川 幸助' | CSV='古川 幸助' | Match=True
#   company_name: JSON='株式会社 アルファドライブ' | CSV='株式会社アルファドライブ' | Match=False
#   company_address: JSON='None' | CSV='〒108-0073 東京都港区三田1-4-28 三田国際ビル' | Match=False
#   phone_number: JSON='03-3452-1111' | CSV='03-3452-1111' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0062' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0062.json:
#   full_name: JSON='菊地 乗' | CSV='菊地 栞' | Match=False
#   company_name: JSON='株式会社サンセット' | CSV='合同会社サンセット' | Match=False
#   company_address: JSON='None' | CSV='〒900-0015 沖縄県那覇市久茂地1-1-1 パレットくもじ' | Match=False
#   phone_number: JSON='098-867-1171' | CSV='098-867-1171' | Match=True
#   File Accuracy: 1/4 (25.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0063' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0063.json:
#   full_name: JSON='千葉雄大' | CSV='千葉 雄大' | Match=False
#   company_name: JSON='株式会社アルファドライブ' | CSV='株式会社アルファドライブ' | Match=True
#   company_address: JSON='None' | CSV='〒108-0073 東京都港区三田1-4-28 三田国際ビル' | Match=False
#   phone_number: JSON='03-3452-1113' | CSV='03-3452-1113' | Match=True
#   File Accuracy: 2/4 (50.00%)
# ----------------------------------------
# Looking for 'Redactor_sample_0064' in master_labels...
#   ✓ Found match!
#
# Comparing paddle_Redactor_sample_0064.json:
#   full_name: JSON='None' | CSV='上野 莉奈' | Match=False
#   company_name: JSON='None' | CSV='合同会社サンセット' | Match=False
#   company_address: JSON='None' | CSV='〒900-0015 沖縄県那覇市久茂地1-1-1 パレットくもじ' | Match=False
#   phone_number: JSON='None' | CSV='098-867-1172' | Match=False
#   File Accuracy: 0/4 (0.00%)
# ----------------------------------------
#
# ================================================================================
# OVERALL STATISTICS
# ================================================================================
#
# Overall Accuracy: 122/256 (47.66%)
#
# ----------------------------------------
# Per-Column Accuracy:
# ----------------------------------------
#   full_name           :  40/ 64 ( 62.50%)
#   company_name        :  30/ 64 ( 46.88%)
#   company_address     :   0/ 64 (  0.00%)
#   phone_number        :  52/ 64 ( 81.25%)
#
# ----------------------------------------
# Per-File Accuracy:
# ----------------------------------------
#   paddle_Redactor_sample_0001.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0002.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0003.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0004.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0005.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0006.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0007.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0008.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0009.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0010.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0011.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0012.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0013.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0014.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0015.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0016.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0017.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0018.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0019.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0020.json        : 0/4 (  0.00%)
#   paddle_Redactor_sample_0021.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0022.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0023.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0024.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0025.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0026.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0027.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0028.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0029.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0030.json        : 0/4 (  0.00%)
#   paddle_Redactor_sample_0031.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0032.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0033.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0034.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0035.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0036.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0037.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0038.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0039.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0040.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0041.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0042.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0043.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0044.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0045.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0046.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0047.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0048.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0049.json        : 3/4 ( 75.00%)
#   paddle_Redactor_sample_0050.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0051.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0052.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0053.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0054.json        : 0/4 (  0.00%)
#   paddle_Redactor_sample_0055.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0056.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0057.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0058.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0059.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0060.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0061.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0062.json        : 1/4 ( 25.00%)
#   paddle_Redactor_sample_0063.json        : 2/4 ( 50.00%)
#   paddle_Redactor_sample_0064.json        : 0/4 (  0.00%)
#
# ================================================================================
# Summary Statistics:
#   Mean Accuracy: 47.66%
#   Median Accuracy: 50.00%
#   Min Accuracy: 0.00%
#   Max Accuracy: 75.00%
#   Std Dev: 21.23%
