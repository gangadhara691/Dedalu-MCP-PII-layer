# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob
import numpy as np
from paddleocr import PaddleOCR
import pdf2image
import pytesseract

# %% [markdown]
# # pdf2txt

# %%
def pdf2txt_tesseract(fn, folder_in, folder_out, override=False):
    try:
        
        output_filename = folder_out+'paddle_' + fn.replace('.pdf', '.txt')
        if not os.path.exists(output_filename) or override:
            
            pages = pdf2image.convert_from_path(folder_in+fn, dpi=300)
            print(f"PDF converted to {len(pages)} page(s)")
            
            # Extract text from each page using OCR
            extracted_text = ""
            for i, page in enumerate(pages):
                print(f"Processing page {i+1}...")
                # Use pytesseract to extract text from the image
                page_text = pytesseract.image_to_string(page, lang='jpn')
                extracted_text += f"\n--- Page {i+1} ---\n"
                extracted_text += page_text.replace('\n','')
                extracted_text += "\n"
            
            print(f"OCR extraction completed. Total characters extracted: {len(extracted_text)}")
            
            # Display first 500 characters as preview
            print("\n--- Text Preview (first 500 characters) ---")
            print(extracted_text.replace(' ', '').replace('\n','')[:50])
            
            # Save extracted text to a file
            output_filename = folder_out+'tesseract_' + fn.replace('.pdf', '.txt')

            with open(output_filename, 'w', encoding='utf-8') as f:
                f.write(extracted_text)
            print(f"\nFull extracted text saved to: {output_filename}")
            
    except Exception as e:
        print(f"Error processing PDF: {str(e)}")
        
        
def pdf2txt_paddle(fn, folder_in, folder_out, override = False):
    try:
        
        output_filename = folder_out+'paddle_' + fn.replace('.pdf', '.txt')
        if not os.path.exists(output_filename) or override:
        # Initialize PaddleOCR for Japanese with updated parameter
        # Use use_textline_orientation instead of deprecated use_angle_cls
            ocr = PaddleOCR(lang='japan')
            
            pages = pdf2image.convert_from_path(folder_in+fn, dpi=300)
            print(f"PDF converted to {len(pages)} page(s)")
            
            # Extract text from each page using OCR
            extracted_text = ""
            for i, page in enumerate(pages):
                print(f"Processing page {i+1}...")
                
                # Convert PIL image to numpy array for PaddleOCR
                page_array = np.array(page)
                
                # Use PaddleOCR to extract text from the image
                try:
                    result = ocr.ocr(page_array, cls=True)
                    
                    # Extract text from OCR results
                    page_text = ""
                    if result and result[0]:  # Check if OCR found any text
                        for line in result[0]:
                            if line and len(line) >= 2 and line[1] and line[1][0]:  # Check if text exists
                                page_text += line[1][0] + "\n"
                    
                    extracted_text += f"\n--- Page {i+1} ---\n"
                    extracted_text += page_text.replace('\n','')
                    extracted_text += "\n"
                    
                except Exception as ocr_error:
                    print(f"OCR error on page {i+1}: {str(ocr_error)}")
                    extracted_text += f"\n--- Page {i+1} (OCR Error) ---\n"
                    extracted_text += f"Error: {str(ocr_error)}\n\n"
            
            print(f"OCR extraction completed. Total characters extracted: {len(extracted_text)}")
            
            # Display first 500 characters as preview
            print("\n--- Text Preview (first 500 characters) ---")
            print(extracted_text.replace(' ', '')[:50])
                
            with open(output_filename, 'w', encoding='utf-8') as f:
                f.write(extracted_text)
            print(f"\nFull extracted text saved to: {output_filename}")
            
    except Exception as e:
        print(f"Error processing PDF: {str(e)}")

# %%
# pdf_folder='../data/pdf/'
pdf_folder='../data/data_generation/generations/Generation_9_10-43am/pdf/'
txt_folder='../data/txt/'
fns = glob.glob(f'{pdf_folder}*.pdf')
fns = sorted([fn.split('/')[-1] for fn in fns ])

override = True
for fn in fns:
    pdf2txt_tesseract(fn,pdf_folder,txt_folder, override)
    pdf2txt_paddle(fn,pdf_folder,txt_folder, override)
# Out:
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 694
#
# --- Text Preview (first 500 characters) ---
# ---Page1---氏名(フルネーム)会社名会社所在地電話番号令和7年10月11日労働条件通知書兼
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0001.txt
# [2025/10/12 11:29:50] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:29:50] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:29:51] ppocr DEBUG: dt_boxes num : 101, elapsed : 0.18744921684265137
# [2025/10/12 11:29:54] ppocr DEBUG: rec_res num  : 101, elapsed : 2.910832405090332
# OCR extraction completed. Total characters extracted: 580
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0001.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 957
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)キ
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0002.txt
# [2025/10/12 11:29:55] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:29:55] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:29:55] ppocr DEBUG: dt_boxes num : 101, elapsed : 0.10553622245788574
# [2025/10/12 11:29:58] ppocr DEBUG: rec_res num  : 101, elapsed : 2.4745588302612305
# OCR extraction completed. Total characters extracted: 580
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名[フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0002.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 879
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)エ
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0003.txt
# [2025/10/12 11:29:59] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:00] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:00] ppocr DEBUG: dt_boxes num : 100, elapsed : 0.10334539413452148
# [2025/10/12 11:30:02] ppocr DEBUG: rec_res num  : 100, elapsed : 2.4556305408477783
# OCR extraction completed. Total characters extracted: 580
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0003.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 885
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)チ
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0004.txt
# [2025/10/12 11:30:04] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:04] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:04] ppocr DEBUG: dt_boxes num : 100, elapsed : 0.10824012756347656
# [2025/10/12 11:30:07] ppocr DEBUG: rec_res num  : 100, elapsed : 2.556852102279663
# OCR extraction completed. Total characters extracted: 579
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和７年10月11日労働条件通知書兼雇用契約書(シンプル)氏名[フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0004.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 957
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)ル
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0005.txt
# [2025/10/12 11:30:08] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:09] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:09] ppocr DEBUG: dt_boxes num : 101, elapsed : 0.10718917846679688
# [2025/10/12 11:30:11] ppocr DEBUG: rec_res num  : 101, elapsed : 2.5043208599090576
# OCR extraction completed. Total characters extracted: 580
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0005.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 956
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)ア
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0006.txt
# [2025/10/12 11:30:13] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:13] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:13] ppocr DEBUG: dt_boxes num : 101, elapsed : 0.10487651824951172
# [2025/10/12 11:30:16] ppocr DEBUG: rec_res num  : 101, elapsed : 2.431363582611084
# OCR extraction completed. Total characters extracted: 580
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名[フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0006.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 688
#
# --- Text Preview (first 500 characters) ---
# ---Page1---氏名(フルネーム)会社名会社所在地電話番号令和7年10月11日労働条件通知書兼
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0007.txt
# [2025/10/12 11:30:17] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:18] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:18] ppocr DEBUG: dt_boxes num : 101, elapsed : 0.10560178756713867
# [2025/10/12 11:30:20] ppocr DEBUG: rec_res num  : 101, elapsed : 2.4379520416259766
# OCR extraction completed. Total characters extracted: 579
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名[フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0007.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 873
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)イ
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0008.txt
# [2025/10/12 11:30:22] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:22] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:22] ppocr DEBUG: dt_boxes num : 100, elapsed : 0.10466361045837402
# [2025/10/12 11:30:25] ppocr DEBUG: rec_res num  : 100, elapsed : 2.4004344940185547
# OCR extraction completed. Total characters extracted: 580
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和７年10月11日労働条件通知書兼雇用契約書(シンプル)氏名[フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0008.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 866
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)オ
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0009.txt
# [2025/10/12 11:30:26] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:27] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:27] ppocr DEBUG: dt_boxes num : 98, elapsed : 0.10427379608154297
# [2025/10/12 11:30:29] ppocr DEBUG: rec_res num  : 98, elapsed : 2.4446871280670166
# OCR extraction completed. Total characters extracted: 581
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和７年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0009.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 945
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)フ
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0010.txt
# [2025/10/12 11:30:31] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:31] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:31] ppocr DEBUG: dt_boxes num : 103, elapsed : 0.10758042335510254
# [2025/10/12 11:30:34] ppocr DEBUG: rec_res num  : 103, elapsed : 2.6705052852630615
# OCR extraction completed. Total characters extracted: 584
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名[フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0010.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 869
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)ア
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0011.txt
# [2025/10/12 11:30:36] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:36] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:36] ppocr DEBUG: dt_boxes num : 99, elapsed : 0.10572075843811035
# [2025/10/12 11:30:39] ppocr DEBUG: rec_res num  : 99, elapsed : 2.506775379180908
# OCR extraction completed. Total characters extracted: 584
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和７年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0011.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 945
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)マ
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0012.txt
# [2025/10/12 11:30:40] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:30:40] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:30:41] ppocr DEBUG: dt_boxes num : 103, elapsed : 0.10869717597961426
# [2025/10/12 11:30:43] ppocr DEBUG: rec_res num  : 103, elapsed : 2.625112533569336
# OCR extraction completed. Total characters extracted: 586
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0012.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 957
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日労働条件通知書兼雇用契約書(シンプル)氏名(フルネーム)ム
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0013.txt
# ...
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:34:06] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:34:06] ppocr DEBUG: dt_boxes num : 45, elapsed : 0.11341238021850586
# [2025/10/12 11:34:08] ppocr DEBUG: rec_res num  : 45, elapsed : 1.3402268886566162
# OCR extraction completed. Total characters extracted: 269
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日雇用条件通知書[簡易)氏名[フルネーム）野村美穂会社名
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0060.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 383
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日選用条件通知書(簡易)氏名(フルネーム)古川幸助会社名株式
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0061.txt
# [2025/10/12 11:34:09] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:34:09] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:34:09] ppocr DEBUG: dt_boxes num : 46, elapsed : 0.10667705535888672
# [2025/10/12 11:34:11] ppocr DEBUG: rec_res num  : 46, elapsed : 1.3204247951507568
# OCR extraction completed. Total characters extracted: 273
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日雇用条件通知書[簡易)氏名[フルネーム）古川幸助会社名
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0061.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 376
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日選用条件通知書(簡易)氏名(フルネーム)菊地馬会社名合同会
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0062.txt
# [2025/10/12 11:34:12] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:34:12] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:34:12] ppocr DEBUG: dt_boxes num : 42, elapsed : 0.11107110977172852
# [2025/10/12 11:34:14] ppocr DEBUG: rec_res num  : 42, elapsed : 1.3139722347259521
# OCR extraction completed. Total characters extracted: 272
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日雇用条件通知書[簡易)氏名（フルネーム）菊地乗会社名合
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0062.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 387
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日選用条件通知書(簡易)氏名(フルネーム)千葉雄大会社名株式
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0063.txt
# [2025/10/12 11:34:15] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:34:15] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:34:15] ppocr DEBUG: dt_boxes num : 46, elapsed : 0.10751748085021973
# [2025/10/12 11:34:17] ppocr DEBUG: rec_res num  : 46, elapsed : 1.328916072845459
# OCR extraction completed. Total characters extracted: 274
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日雇用条件通知書[簡易)氏名（フルネーム）千葉雄大会社名
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0063.txt
# PDF converted to 1 page(s)
# Processing page 1...
# OCR extraction completed. Total characters extracted: 377
#
# --- Text Preview (first 500 characters) ---
# ---Page1---令和7年10月11日選用条件通知書(簡易)氏名(フルネーム)上野莉奈会社名合同
#
# Full extracted text saved to: ../data/txt/tesseract_Redactor_sample_0064.txt
# [2025/10/12 11:34:18] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/df/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/df/.paddleocr/whl/rec/japan/japan_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/df/Desktop/gg/vs/redact/.venv/lib/python3.12/site-packages/paddleocr/ppocr/utils/dict/japan_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/df/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='japan', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# PDF converted to 1 page(s)
# Processing page 1...
# [2025/10/12 11:34:18] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2025/10/12 11:34:18] ppocr DEBUG: dt_boxes num : 43, elapsed : 0.10495948791503906
# [2025/10/12 11:34:20] ppocr DEBUG: rec_res num  : 43, elapsed : 1.2976343631744385
# OCR extraction completed. Total characters extracted: 261
#
# --- Text Preview (first 500 characters) ---
#
# ---Page1---
# 令和7年10月11日雇用条件通知書[簡易)氏名[フルネーム)上野勒奈会社名
#
# Full extracted text saved to: ../data/txt/paddle_Redactor_sample_0064.txt

# %% [markdown]
# # txt Eval

# %%
txt_folder = '../data/unstructured_pii/'

# %%
import pandas as pd
import glob
import os


def normalize(txt):
    txt = txt.replace(' ', '').replace('\n', '')
    txt = txt.replace('〒','')
    return txt

master_labels_fn = '../data/data_generation/master_label.csv'

# Read master labels
master_labels = pd.read_csv(master_labels_fn)
print("Master Labels:")
print(master_labels)
print("\n" + "="*80 + "\n")

# Get all txt files
txt_files = glob.glob(txt_folder + '*.txt')
txt_files = sorted(txt_files)

# Columns to check (excluding file_name and template_id)
columns_to_check = ['full_name', 'company_name', 'company_address', 'phone_number']

# Results storage
results = []

for txt_file in txt_files:
    txt_filename = os.path.basename(txt_file)
    
    # Extract base filename (e.g., "Redactor_sample_0001" from "paddle_Redactor_sample_0001.txt")
    # This handles both tesseract_ and paddle_ prefixes
    base_name = txt_filename.replace('paddle_', '').replace('tesseract_', '').replace('.txt', '')
    
    # Find corresponding row in master_labels
    label_row = master_labels[master_labels['file_name'] == base_name]
    
    if label_row.empty:
        print(f"Warning: No labels found for {base_name}")
        continue
    
    # Read txt file content
    with open(txt_file, 'r', encoding='utf-8') as f:
        txt_content = f.read()
    
    # Remove spaces and newlines for better matching
    txt_content_normalized = normalize(txt_content)
    
    
    print(f"Evaluating: {txt_filename}")
    print(f"Base name: {base_name}")
    
    # Check each column
    found_count = 0
    total_count = 0
    column_results = {}
    
    for col in columns_to_check:
        label_value = str(label_row[col].values[0])
        if pd.notna(label_value) and label_value != 'nan':
            total_count += 1
            # Normalize label value (remove spaces)
            label_normalized = normalize(label_value)
            
            # Check if label is in txt content
            if label_normalized in txt_content_normalized:
                found_count += 1
                column_results[col] = 'FOUND'
                print(f"  ✓ {col}: '{label_value}' - FOUND")
            else:
                column_results[col] = 'NOT FOUND'
                print(f"  ✗ {col}: '{label_value}' - NOT FOUND")
        else:
            column_results[col] = 'N/A'
    
    # Calculate percentage
    percentage = (found_count / total_count * 100) if total_count > 0 else 0
    
    print(f"  → Found: {found_count}/{total_count} ({percentage:.1f}%)")
    print()
    
    # Store results
    result_dict = {
        'txt_file': txt_filename,
        'base_name': base_name,
        'found': found_count,
        'total': total_count,
        'percentage': percentage
    }
    result_dict.update(column_results)
    results.append(result_dict)

# Create results DataFrame
results_df = pd.DataFrame(results)
print("\n" + "="*80)
print("SUMMARY OF RESULTS:")
print("="*80)
print(results_df[['txt_file', 'found', 'total', 'percentage']])

print("\n" + "="*80)
print("DETAILED RESULTS BY COLUMN:")
print("="*80)
print(results_df)

# Save results to CSV
output_file = '../data/ocr_evaluation_results.csv'
results_df.to_csv(output_file, index=False)
print(f"\nResults saved to: {output_file}")
# Out:
# Master Labels:
#                file_name  full_name    company_name  \
# 0   Redactor_sample_0001   ソフィア・ミラー   株式会社オリオンシステムズ
# 1   Redactor_sample_0002   キム・ミンジュン      ネクサス貿易合同会社
# 2   Redactor_sample_0003  エミリー・ブラウン  スカイネット・ロジスティクス
# 3   Redactor_sample_0004    チャン・ウェイ   株式会社アース・クリエイト
# 4   Redactor_sample_0005   ルイス・カルロス   株式会社オリオンシステムズ
# ..                   ...        ...             ...
# 59  Redactor_sample_0060      野村 美穂        リバーサイド工業
# 60  Redactor_sample_0061      古川 幸助    株式会社アルファドライブ
# 61  Redactor_sample_0062       菊地 栞       合同会社サンセット
# 62  Redactor_sample_0063      千葉 雄大    株式会社アルファドライブ
# 63  Redactor_sample_0064      上野 莉奈       合同会社サンセット
#
#                                company_address  phone_number  template_id
# 0      〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ  03-6262-1212            1
# 1   〒220-0012 神奈川県横浜市西区みなとみらい2-2-1 横浜ランドマークタワー  045-222-5501            1
# 2           〒530-0011 大阪府大阪市北区大深町3-1 グランフロント大阪  06-6372-6789            1
# 3         〒812-0012 福岡県福岡市博多区博多駅中央街1-1 JR博多シティ  092-475-8000            1
# 4      〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ  03-6262-1213            1
# ..                                         ...           ...          ...
# 59    〒950-0088 新潟県新潟市中央区万代1-6-1 万代シテイバスセンタービル  025-246-6112            4
# 60              〒108-0073 東京都港区三田1-4-28 三田国際ビル  03-3452-1111            4
# 61            〒900-0015 沖縄県那覇市久茂地1-1-1 パレットくもじ  098-867-1171            4
# 62              〒108-0073 東京都港区三田1-4-28 三田国際ビル  03-3452-1113            4
# 63            〒900-0015 沖縄県那覇市久茂地1-1-1 パレットくもじ  098-867-1172            4
#
# [64 rows x 6 columns]
#
# ================================================================================
#
# Evaluating: paddle_Redactor_sample_0001.txt
# Base name: Redactor_sample_0001
#   ✓ full_name: 'ソフィア・ミラー' - FOUND
#   ✓ company_name: '株式会社オリオンシステムズ' - FOUND
#   ✗ company_address: '〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ' - NOT FOUND
#   ✓ phone_number: '03-6262-1212' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0002.txt
# Base name: Redactor_sample_0002
#   ✓ full_name: 'キム・ミンジュン' - FOUND
#   ✗ company_name: 'ネクサス貿易合同会社' - NOT FOUND
#   ✗ company_address: '〒220-0012 神奈川県横浜市西区みなとみらい2-2-1 横浜ランドマークタワー' - NOT FOUND
#   ✓ phone_number: '045-222-5501' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0003.txt
# Base name: Redactor_sample_0003
#   ✓ full_name: 'エミリー・ブラウン' - FOUND
#   ✓ company_name: 'スカイネット・ロジスティクス' - FOUND
#   ✗ company_address: '〒530-0011 大阪府大阪市北区大深町3-1 グランフロント大阪' - NOT FOUND
#   ✓ phone_number: '06-6372-6789' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0004.txt
# Base name: Redactor_sample_0004
#   ✗ full_name: 'チャン・ウェイ' - NOT FOUND
#   ✓ company_name: '株式会社アース・クリエイト' - FOUND
#   ✗ company_address: '〒812-0012 福岡県福岡市博多区博多駅中央街1-1 JR博多シティ' - NOT FOUND
#   ✓ phone_number: '092-475-8000' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0005.txt
# Base name: Redactor_sample_0005
#   ✓ full_name: 'ルイス・カルロス' - FOUND
#   ✓ company_name: '株式会社オリオンシステムズ' - FOUND
#   ✗ company_address: '〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ' - NOT FOUND
#   ✓ phone_number: '03-6262-1213' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0006.txt
# Base name: Redactor_sample_0006
#   ✓ full_name: 'アナ・ペレイラ' - FOUND
#   ✗ company_name: 'ネクサス貿易合同会社' - NOT FOUND
#   ✗ company_address: '〒220-0012 神奈川県横浜市西区みなとみらい2-2-1 横浜ランドマークタワー' - NOT FOUND
#   ✓ phone_number: '045-222-5502' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0007.txt
# Base name: Redactor_sample_0007
#   ✓ full_name: 'ダニエル・リベラ' - FOUND
#   ✓ company_name: 'スカイネット・ロジスティクス' - FOUND
#   ✗ company_address: '〒530-0011 大阪府大阪市北区大深町3-1 グランフロント大阪' - NOT FOUND
#   ✓ phone_number: '06-6372-6790' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0008.txt
# Base name: Redactor_sample_0008
#   ✓ full_name: 'イワン・ポポフ' - FOUND
#   ✓ company_name: '株式会社アース・クリエイト' - FOUND
#   ✗ company_address: '〒812-0012 福岡県福岡市博多区博多駅中央街1-1 JR博多シティ' - NOT FOUND
#   ✓ phone_number: '092-475-8001' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0009.txt
# Base name: Redactor_sample_0009
#   ✓ full_name: 'オリビア・マーティン' - FOUND
#   ✓ company_name: 'ホライズン・コンサルティング' - FOUND
#   ✗ company_address: '〒106-6150 東京都港区六本木6-10-1 六本木ヒルズ森タワー' - NOT FOUND
#   ✓ phone_number: '03-6406-6000' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0010.txt
# Base name: Redactor_sample_0010
#   ✓ full_name: 'ファティマ・アリ' - FOUND
#   ✓ company_name: 'パシフィック・ゲートウェイ' - FOUND
#   ✗ company_address: '〒650-0044 兵庫県神戸市中央区東川崎町1-6-1 神戸ハーバーランドumie' - NOT FOUND
#   ✓ phone_number: '078-382-7100' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0011.txt
# Base name: Redactor_sample_0011
#   ✓ full_name: 'アレクサンダー・シュミット' - FOUND
#   ✓ company_name: 'ホライズン・コンサルティング' - FOUND
#   ✓ company_address: '〒106-6150 東京都港区六本木6-10-1 六本木ヒルズ森タワー' - FOUND
#   ✓ phone_number: '03-6406-6001' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0012.txt
# Base name: Redactor_sample_0012
#   ✓ full_name: 'マリア・ゴンザレス' - FOUND
#   ✓ company_name: 'パシフィック・ゲートウェイ' - FOUND
#   ✗ company_address: '〒650-0044 兵庫県神戸市中央区東川崎町1-6-1 神戸ハーバーランドumie' - NOT FOUND
#   ✓ phone_number: '078-382-7101' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0013.txt
# Base name: Redactor_sample_0013
#   ✓ full_name: 'ムハンマド・イクバル' - FOUND
#   ✓ company_name: '株式会社コスモ企画' - FOUND
#   ✓ company_address: '〒160-0023 東京都新宿区西新宿6-5-1 新宿アイランドタワー' - FOUND
#   ✓ phone_number: '03-3348-1111' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0014.txt
# Base name: Redactor_sample_0014
#   ✓ full_name: 'クロエ・ルコント' - FOUND
#   ✓ company_name: 'アクアソリューションズ合同会社' - FOUND
#   ✗ company_address: '〒450-6201 愛知県名古屋市中村区名駅4-7-1 ミッドランドスクエア' - NOT FOUND
#   ✓ phone_number: '052-527-8888' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0015.txt
# Base name: Redactor_sample_0015
#   ✓ full_name: 'ラファエル・フェルナンデス' - FOUND
#   ✓ company_name: '株式会社コスモ企画' - FOUND
#   ✓ company_address: '〒160-0023 東京都新宿区西新宿6-5-1 新宿アイランドタワー' - FOUND
#   ✓ phone_number: '03-3348-1112' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0016.txt
# Base name: Redactor_sample_0016
#   ✓ full_name: 'ユリア・ノビコワ' - FOUND
#   ✓ company_name: 'アクアソリューションズ合同会社' - FOUND
#   ✗ company_address: '〒450-6201 愛知県名古屋市中村区名駅4-7-1 ミッドランドスクエア' - NOT FOUND
#   ✓ phone_number: '052-527-8889' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0017.txt
# Base name: Redactor_sample_0017
#   ✓ full_name: '佐々木 翔太' - FOUND
#   ✓ company_name: '日の出製作所' - FOUND
#   ✗ company_address: '〒131-8634 東京都墨田区押上1-1-2 東京スカイツリーイーストタワー' - NOT FOUND
#   ✓ phone_number: '03-5809-5050' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0018.txt
# Base name: Redactor_sample_0018
#   ✓ full_name: '山田 優子' - FOUND
#   ✓ company_name: '株式会社ミナト電機' - FOUND
#   ✗ company_address: '〒231-0001 神奈川県横浜市中区新港1-3-1 横浜赤レンガ倉庫' - NOT FOUND
#   ✓ phone_number: '045-211-1555' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0019.txt
# Base name: Redactor_sample_0019
#   ✓ full_name: '木下 拓海' - FOUND
#   ✗ company_name: '関西スチール株式会社' - NOT FOUND
#   ✗ company_address: '〒542-0076 大阪府大阪市中央区難波5-1-60 なんばパークス' - NOT FOUND
#   ✓ phone_number: '06-6644-7100' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0020.txt
# Base name: Redactor_sample_0020
#   ✓ full_name: '森 りん' - FOUND
#   ✗ company_name: '中部ファインテック' - NOT FOUND
#   ✗ company_address: '〒460-0008 愛知県名古屋市中区栄3-5-1 名古屋三越' - NOT FOUND
#   ✓ phone_number: '052-252-1111' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0021.txt
# Base name: Redactor_sample_0021
#   ✓ full_name: '池田 蓮' - FOUND
#   ✗ company_name: '日の出製作所' - NOT FOUND
#   ✗ company_address: '〒131-8634 東京都墨田区押上1-1-2 東京スカイツリーイーストタワー' - NOT FOUND
#   ✓ phone_number: '03-5809-5051' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0022.txt
# Base name: Redactor_sample_0022
#   ✓ full_name: '橋本 あかり' - FOUND
#   ✓ company_name: '株式会社ミナト電機' - FOUND
#   ✗ company_address: '〒231-0001 神奈川県横浜市中区新港1-3-1 横浜赤レンガ倉庫' - NOT FOUND
#   ✓ phone_number: '045-211-1556' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0023.txt
# Base name: Redactor_sample_0023
#   ✓ full_name: '石川 大地' - FOUND
#   ✗ company_name: '関西スチール株式会社' - NOT FOUND
#   ✗ company_address: '〒542-0076 大阪府大阪市中央区難波5-1-60 なんばパークス' - NOT FOUND
#   ✓ phone_number: '06-6644-7102' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0024.txt
# Base name: Redactor_sample_0024
#   ✓ full_name: '清水 結衣' - FOUND
#   ✓ company_name: '中部ファインテック' - FOUND
#   ✗ company_address: '〒460-0008 愛知県名古屋市中区栄3-5-1 名古屋三越' - NOT FOUND
#   ✓ phone_number: '052-252-1113' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0025.txt
# Base name: Redactor_sample_0025
#   ✓ full_name: '前田 悠斗' - FOUND
#   ✓ company_name: '株式会社サンライズ物流' - FOUND
#   ✓ company_address: '〒135-8625 東京都江東区豊洲2-4-9 アーバンドック ららぽーと豊洲' - FOUND
#   ✓ phone_number: '03-6910-1234' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0026.txt
# Base name: Redactor_sample_0026
#   ✓ full_name: '藤井 菜々' - FOUND
#   ✓ company_name: 'サクラ精密機器' - FOUND
#   ✗ company_address: '〒330-9555 埼玉県さいたま市大宮区桜木町1-7-5 ソニックシティビル' - NOT FOUND
#   ✓ phone_number: '048-647-4111' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0027.txt
# Base name: Redactor_sample_0027
#   ✓ full_name: '岡田 航' - FOUND
#   ✓ company_name: '株式会社サンライズ物流' - FOUND
#   ✓ company_address: '〒135-8625 東京都江東区豊洲2-4-9 アーバンドック ららぽーと豊洲' - FOUND
#   ✓ phone_number: '03-6910-1235' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0028.txt
# Base name: Redactor_sample_0028
#   ✓ full_name: '後藤 美月' - FOUND
#   ✓ company_name: 'サクラ精密機器' - FOUND
#   ✗ company_address: '〒330-9555 埼玉県さいたま市大宮区桜木町1-7-5 ソニックシティビル' - NOT FOUND
#   ✓ phone_number: '048-647-4112' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0029.txt
# Base name: Redactor_sample_0029
#   ✗ full_name: '村上 颯太' - NOT FOUND
#   ✗ company_name: 'フロンティア・エージェンシー' - NOT FOUND
#   ✗ company_address: '〒150-0002 東京都渋谷区渋谷2-24-12 渋谷スクランブルスクエア' - NOT FOUND
#   ✓ phone_number: '03-4221-4280' - FOUND
#   → Found: 1/4 (25.0%)
#
# Evaluating: paddle_Redactor_sample_0030.txt
# Base name: Redactor_sample_0030
#   ✗ full_name: '長谷川 莉子' - NOT FOUND
#   ✓ company_name: '株式会社京葉エンジニアリング' - FOUND
#   ✗ company_address: '〒261-7132 千葉県千葉市美浜区中瀬2-6-1 WBGマリブウエスト' - NOT FOUND
#   ✗ phone_number: '043-297-3000' - NOT FOUND
#   → Found: 1/4 (25.0%)
#
# Evaluating: paddle_Redactor_sample_0031.txt
# Base name: Redactor_sample_0031
#   ✓ full_name: '西村 陽菜' - FOUND
#   ✗ company_name: 'フロンティア・エージェンシー' - NOT FOUND
#   ✗ company_address: '〒150-0002 東京都渋谷区渋谷2-24-12 渋谷スクランブルスクエア' - NOT FOUND
#   ✓ phone_number: '03-4221-4281' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0032.txt
# Base name: Redactor_sample_0032
#   ✓ full_name: '石井 涼介' - FOUND
#   ✓ company_name: '株式会社京葉エンジニアリング' - FOUND
#   ✗ company_address: '〒261-7132 千葉県千葉市美浜区中瀬2-6-1 WBGマリブウエスト' - NOT FOUND
#   ✓ phone_number: '043-297-3001' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0033.txt
# Base name: Redactor_sample_0033
#   ✓ full_name: '山口 智也' - FOUND
#   ✓ company_name: '株式会社デジタル・ウェイブ' - FOUND
#   ✗ company_address: '〒105-7333 東京都港区東新橋1-9-1 東京汐留ビルディング' - NOT FOUND
#   ✗ phone_number: '03-6252-3456' - NOT FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0034.txt
# Base name: Redactor_sample_0034
#   ✓ full_name: '宮崎 楓' - FOUND
#   ✓ company_name: 'アーバンリサーチ株式会社' - FOUND
#   ✗ company_address: '〒550-0015 大阪府大阪市西区南堀江1-14-26 中澤唐木ビル' - NOT FOUND
#   ✓ phone_number: '06-6536-2323' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0035.txt
# Base name: Redactor_sample_0035
#   ✓ full_name: '野口 和樹' - FOUND
#   ✓ company_name: '株式会社アイリス' - FOUND
#   ✗ company_address: '〒980-0021 宮城県仙台市青葉区中央1-2-3 仙台マークワン' - NOT FOUND
#   ✓ phone_number: '022-716-1111' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0036.txt
# Base name: Redactor_sample_0036
#   ✓ full_name: '大塚 さくら' - FOUND
#   ✓ company_name: '株式会社ネオ・コーポレーション' - FOUND
#   ✗ company_address: '〒060-0005 北海道札幌市中央区北5条西2-5 JRタワー' - NOT FOUND
#   ✓ phone_number: '011-209-5100' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0037.txt
# Base name: Redactor_sample_0037
#   ✓ full_name: '松田 竜也' - FOUND
#   ✓ company_name: '株式会社デジタル・ウェイブ' - FOUND
#   ✗ company_address: '〒105-7333 東京都港区東新橋1-9-1 東京汐留ビルディング' - NOT FOUND
#   ✓ phone_number: '03-6252-3457' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0038.txt
# Base name: Redactor_sample_0038
#   ✓ full_name: '小野 恵子' - FOUND
#   ✗ company_name: 'アーバンリサーチ株式会社' - NOT FOUND
#   ✗ company_address: '〒550-0015 大阪府大阪市西区南堀江1-14-26 中澤唐木ビル' - NOT FOUND
#   ✓ phone_number: '06-6536-2324' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0039.txt
# Base name: Redactor_sample_0039
#   ✓ full_name: '田村 亮' - FOUND
#   ✓ company_name: '株式会社アイリス' - FOUND
#   ✗ company_address: '〒980-0021 宮城県仙台市青葉区中央1-2-3 仙台マークワン' - NOT FOUND
#   ✓ phone_number: '022-716-1112' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0040.txt
# Base name: Redactor_sample_0040
#   ✓ full_name: '杉山 結菜' - FOUND
#   ✓ company_name: '株式会社ネオ・コーポレーション' - FOUND
#   ✗ company_address: '〒060-0005 北海道札幌市中央区北5条西2-5 JRタワー' - NOT FOUND
#   ✓ phone_number: '011-209-5101' - FOUND
#   → Found: 3/4 (75.0%)
#
#
# ================================================================================
# SUMMARY OF RESULTS:
# ================================================================================
#                            txt_file  found  total  percentage
# 0   paddle_Redactor_sample_0001.txt      3      4        75.0
# 1   paddle_Redactor_sample_0002.txt      2      4        50.0
# 2   paddle_Redactor_sample_0003.txt      3      4        75.0
# 3   paddle_Redactor_sample_0004.txt      2      4        50.0
# 4   paddle_Redactor_sample_0005.txt      3      4        75.0
# 5   paddle_Redactor_sample_0006.txt      2      4        50.0
# 6   paddle_Redactor_sample_0007.txt      3      4        75.0
# 7   paddle_Redactor_sample_0008.txt      3      4        75.0
# 8   paddle_Redactor_sample_0009.txt      3      4        75.0
# 9   paddle_Redactor_sample_0010.txt      3      4        75.0
# 10  paddle_Redactor_sample_0011.txt      4      4       100.0
# 11  paddle_Redactor_sample_0012.txt      3      4        75.0
# 12  paddle_Redactor_sample_0013.txt      4      4       100.0
# 13  paddle_Redactor_sample_0014.txt      3      4        75.0
# 14  paddle_Redactor_sample_0015.txt      4      4       100.0
# 15  paddle_Redactor_sample_0016.txt      3      4        75.0
# 16  paddle_Redactor_sample_0017.txt      3      4        75.0
# 17  paddle_Redactor_sample_0018.txt      3      4        75.0
# 18  paddle_Redactor_sample_0019.txt      2      4        50.0
# 19  paddle_Redactor_sample_0020.txt      2      4        50.0
# 20  paddle_Redactor_sample_0021.txt      2      4        50.0
# 21  paddle_Redactor_sample_0022.txt      3      4        75.0
# 22  paddle_Redactor_sample_0023.txt      2      4        50.0
# 23  paddle_Redactor_sample_0024.txt      3      4        75.0
# 24  paddle_Redactor_sample_0025.txt      4      4       100.0
# 25  paddle_Redactor_sample_0026.txt      3      4        75.0
# 26  paddle_Redactor_sample_0027.txt      4      4       100.0
# 27  paddle_Redactor_sample_0028.txt      3      4        75.0
# 28  paddle_Redactor_sample_0029.txt      1      4        25.0
# 29  paddle_Redactor_sample_0030.txt      1      4        25.0
# 30  paddle_Redactor_sample_0031.txt      2      4        50.0
# 31  paddle_Redactor_sample_0032.txt      3      4        75.0
# 32  paddle_Redactor_sample_0033.txt      2      4        50.0
# 33  paddle_Redactor_sample_0034.txt      3      4        75.0
# 34  paddle_Redactor_sample_0035.txt      3      4        75.0
# 35  paddle_Redactor_sample_0036.txt      3      4        75.0
# 36  paddle_Redactor_sample_0037.txt      3      4        75.0
# 37  paddle_Redactor_sample_0038.txt      2      4        50.0
# 38  paddle_Redactor_sample_0039.txt      3      4        75.0
# 39  paddle_Redactor_sample_0040.txt      3      4        75.0
#
# ================================================================================
# DETAILED RESULTS BY COLUMN:
# ================================================================================
#                            txt_file             base_name  found  total  \
# 0   paddle_Redactor_sample_0001.txt  Redactor_sample_0001      3      4
# 1   paddle_Redactor_sample_0002.txt  Redactor_sample_0002      2      4
# 2   paddle_Redactor_sample_0003.txt  Redactor_sample_0003      3      4
# 3   paddle_Redactor_sample_0004.txt  Redactor_sample_0004      2      4
# 4   paddle_Redactor_sample_0005.txt  Redactor_sample_0005      3      4
# 5   paddle_Redactor_sample_0006.txt  Redactor_sample_0006      2      4
# 6   paddle_Redactor_sample_0007.txt  Redactor_sample_0007      3      4
# 7   paddle_Redactor_sample_0008.txt  Redactor_sample_0008      3      4
# 8   paddle_Redactor_sample_0009.txt  Redactor_sample_0009      3      4
# 9   paddle_Redactor_sample_0010.txt  Redactor_sample_0010      3      4
# 10  paddle_Redactor_sample_0011.txt  Redactor_sample_0011      4      4
# 11  paddle_Redactor_sample_0012.txt  Redactor_sample_0012      3      4
# 12  paddle_Redactor_sample_0013.txt  Redactor_sample_0013      4      4
# 13  paddle_Redactor_sample_0014.txt  Redactor_sample_0014      3      4
# 14  paddle_Redactor_sample_0015.txt  Redactor_sample_0015      4      4
# 15  paddle_Redactor_sample_0016.txt  Redactor_sample_0016      3      4
# 16  paddle_Redactor_sample_0017.txt  Redactor_sample_0017      3      4
# 17  paddle_Redactor_sample_0018.txt  Redactor_sample_0018      3      4
# 18  paddle_Redactor_sample_0019.txt  Redactor_sample_0019      2      4
# 19  paddle_Redactor_sample_0020.txt  Redactor_sample_0020      2      4
# 20  paddle_Redactor_sample_0021.txt  Redactor_sample_0021      2      4
# 21  paddle_Redactor_sample_0022.txt  Redactor_sample_0022      3      4
# 22  paddle_Redactor_sample_0023.txt  Redactor_sample_0023      2      4
# 23  paddle_Redactor_sample_0024.txt  Redactor_sample_0024      3      4
# 24  paddle_Redactor_sample_0025.txt  Redactor_sample_0025      4      4
# 25  paddle_Redactor_sample_0026.txt  Redactor_sample_0026      3      4
# 26  paddle_Redactor_sample_0027.txt  Redactor_sample_0027      4      4
# 27  paddle_Redactor_sample_0028.txt  Redactor_sample_0028      3      4
# 28  paddle_Redactor_sample_0029.txt  Redactor_sample_0029      1      4
# 29  paddle_Redactor_sample_0030.txt  Redactor_sample_0030      1      4
# 30  paddle_Redactor_sample_0031.txt  Redactor_sample_0031      2      4
# 31  paddle_Redactor_sample_0032.txt  Redactor_sample_0032      3      4
# 32  paddle_Redactor_sample_0033.txt  Redactor_sample_0033      2      4
# 33  paddle_Redactor_sample_0034.txt  Redactor_sample_0034      3      4
# 34  paddle_Redactor_sample_0035.txt  Redactor_sample_0035      3      4
# 35  paddle_Redactor_sample_0036.txt  Redactor_sample_0036      3      4
# 36  paddle_Redactor_sample_0037.txt  Redactor_sample_0037      3      4
# 37  paddle_Redactor_sample_0038.txt  Redactor_sample_0038      2      4
# 38  paddle_Redactor_sample_0039.txt  Redactor_sample_0039      3      4
# 39  paddle_Redactor_sample_0040.txt  Redactor_sample_0040      3      4
#
#     percentage  full_name company_name company_address phone_number
# 0         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 1         50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 2         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 3         50.0  NOT FOUND        FOUND       NOT FOUND        FOUND
# 4         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 5         50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 6         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 7         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 8         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 9         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 10       100.0      FOUND        FOUND           FOUND        FOUND
# 11        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 12       100.0      FOUND        FOUND           FOUND        FOUND
# 13        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 14       100.0      FOUND        FOUND           FOUND        FOUND
# 15        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 16        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 17        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 18        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 19        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 20        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 21        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 22        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 23        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 24       100.0      FOUND        FOUND           FOUND        FOUND
# 25        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 26       100.0      FOUND        FOUND           FOUND        FOUND
# 27        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 28        25.0  NOT FOUND    NOT FOUND       NOT FOUND        FOUND
# 29        25.0  NOT FOUND        FOUND       NOT FOUND    NOT FOUND
# 30        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 31        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 32        50.0      FOUND        FOUND       NOT FOUND    NOT FOUND
# 33        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 34        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 35        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 36        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 37        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 38        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 39        75.0      FOUND        FOUND       NOT FOUND        FOUND
#
# Results saved to: ../data/ocr_evaluation_results.csv
