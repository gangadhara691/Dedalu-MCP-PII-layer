# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import glob
import numpy as np

# %% [markdown]
# # RemovePII

# %%
import json
import re

def normalize_for_matching(text):
    """Remove spaces, newlines, and other whitespace for matching purposes"""
    return re.sub(r'\s+', '', text)

def remove_pii(fn, txt_folder, json_pii_folder):
    """
    Remove PII information from text file based on JSON labels.
    Handles spaces and newlines in the text content intelligently.
    """
    # Read txt file content
    with open(txt_folder + fn, 'r', encoding='utf-8') as f:
        txt_content = f.read()
        
    # Read JSON PII file content
    json_fn = fn.replace('.txt', '.json')
    with open(json_pii_folder + json_fn, 'r', encoding='utf-8') as f:
        json_pii = json.load(f)
    
    # Track what we remove
    removed_fields = []
    original_txt = txt_content
    
    # Normalize the text for searching (remove all whitespace)
    txt_normalized = normalize_for_matching(txt_content)
    
    # Fields to remove (in order of specificity - longer/more specific first)
    fields_to_check = ['address', 'company_name', 'full_name', 'phone_number']
    
    for field in fields_to_check:
        if field in json_pii and json_pii[field]:
            pii_value = str(json_pii[field])
            pii_normalized = normalize_for_matching(pii_value)
            
            # Find the position in normalized text
            pos = txt_normalized.find(pii_normalized)
            
            if pos != -1:
                # Now find the actual substring in the original text
                # We need to map the normalized position back to the original text
                original_pos = 0
                normalized_pos = 0
                
                # Walk through original text until we reach the position
                while normalized_pos < pos and original_pos < len(txt_content):
                    if not txt_content[original_pos].isspace():
                        normalized_pos += 1
                    original_pos += 1
                
                # Now extract the substring of the same length (accounting for whitespace)
                start_pos = original_pos
                chars_matched = 0
                end_pos = original_pos
                
                while chars_matched < len(pii_normalized) and end_pos < len(txt_content):
                    if not txt_content[end_pos].isspace():
                        chars_matched += 1
                    end_pos += 1
                
                # Extract the actual text that matches (with whitespace)
                actual_match = txt_content[start_pos:end_pos]
                
                # Replace with redaction marker
                redaction = f"[REDACTED_{field.upper()}]"
                txt_content = txt_content[:start_pos] + redaction + txt_content[end_pos:]
                
                # Update normalized text too
                txt_normalized = normalize_for_matching(txt_content)
                
                removed_fields.append(field)
                # print(f"  Removed {field}: '{pii_value}'")
    
    # Save the redacted content
    output_fn = txt_folder.replace('/txt/', '/txt_no_pii/') + fn
    os.makedirs(os.path.dirname(output_fn), exist_ok=True)
    with open(output_fn, 'w', encoding='utf-8') as f:
        f.write(txt_content)
    

    if len(removed_fields) != 4:
        
        print(fn)
        print(json_pii)
        print(removed_fields)

        print("original", original_txt)
        
        print("no pii", txt_content)
        
    return len(removed_fields), removed_fields

# %%
# pdf_folder='../data/pdf/'
txt_folder='../data/txt/'
fns = glob.glob(f'{txt_folder}*.txt')
fns = sorted([fn.split('/')[-1] for fn in fns if 'tess' in fn ])
txt_no_pii_folder = '../data/txt_no_pii/'
json_pii_folder = '../data/json_pii/'
os.makedirs(txt_no_pii_folder, exist_ok=True)

c = 0
for fn in fns[0:38]:
    count, fields = remove_pii(fn, txt_folder, json_pii_folder)
    if count != 4:
        c+=1
        print(f"  WARNING: Expected 4 fields but removed {count}, {fields} on {fn}")

print(c)
# Out:
# tesseract_Redactor_sample_0001.txt
# {'full_name': '早稲田 太郎', 'company_name': 'ソノソフィア・ミラー株式会社オリオンシステムズ', 'address': '東京都千代田区大手町 1-9-2 大手町フィナンシャルシティ03-6262-1212', 'phone_number': '03-6262-1212'}
# ['address', 'company_name', 'full_name']
# original
# --- Page 1 ---
# 氏名 (フルネーム)会社名会社所在地電話番号 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)ソノソフィア・ミラー株式会社オリオンシステムズ〒 100-0004 東京都千代田区大手町 1-9-2 大手町フィナンシャルシティ03-6262-1212次の労働条件によって雇用契約を締結します。雇用期間更新の有無試用期間就業の場所仕事の内容各業時間時間外・休日休日休暇退職金額割増率貞金締切・支払その他V期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新する場合があり得る (基準 : 業務量/成績・態度能カプ経営状況進捗)令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日本社 (上記所在地)産業機械の組立補助・検査・付随事務始業 9.00 終業 18:00 休憩 12:00て13:00所定時間外有 (約 20 時間/月) 休日労働無土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日年次有給 (法定) 特別休暇 (慶事 3 日有給)定年 60 蔵ノ継続雇用 65 歳までその他は就業規則による月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜25%毎月末日締切翌月 25 日支払 (口座振込)社会保険・雇用保険・労災保険加入  使用者 : 代表取締役早稲田太郎           ⑧ (会社名・所在地は上記のとおり)
#
# no pii
# --- Page 1 ---
# 氏名 (フルネーム)会社名会社所在地電話番号 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)[REDACTED_COMPANY_NAME]〒 100-0004[REDACTED_ADDRESS]次の労働条件によって雇用契約を締結します。雇用期間更新の有無試用期間就業の場所仕事の内容各業時間時間外・休日休日休暇退職金額割増率貞金締切・支払その他V期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新する場合があり得る (基準 : 業務量/成績・態度能カプ経営状況進捗)令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日本社 (上記所在地)産業機械の組立補助・検査・付随事務始業 9.00 終業 18:00 休憩 12:00て13:00所定時間外有 (約 20 時間/月) 休日労働無土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日年次有給 (法定) 特別休暇 (慶事 3 日有給)定年 60 蔵ノ継続雇用 65 歳までその他は就業規則による月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜25%毎月末日締切翌月 25 日支払 (口座振込)社会保険・雇用保険・労災保険加入  使用者 : 代表取締役[REDACTED_FULL_NAME]           ⑧ (会社名・所在地は上記のとおり)
#
#   WARNING: Expected 4 fields but removed 3, ['address', 'company_name', 'full_name'] on tesseract_Redactor_sample_0001.txt
# tesseract_Redactor_sample_0004.txt
# {'full_name': '張 ウェイ', 'company_name': '株式会社アース・クリエイト', 'address': '福岡県福岡市博多区博多駅中央街 1-.1 JR 博多シティ', 'phone_number': '092-475-8000'}
# ['address', 'company_name', 'phone_number']
# original
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム) チャン・ウェイ会社名           株式会社アース・クリエイト会社所在地              〒 812-0012 福岡県福岡市博多区博多駅中央街 1-.1 JR 博多シティ電話番号              092-475-8000次の労働条件によって雇用契約を締結します。   雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無     更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所     本社 (上記所在地)仕事の内容     産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日    所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇        年次有給 (法定) 特別休暇 (慶事 3 日有給)退職        定年 60 歳継続雇用 65 蔵までその他は就業規則による金額                月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率          時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                  2596締切・支払     毎月末日締切翌月 25 日支払 (口座振込)その他       社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
# no pii
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム) チャン・ウェイ会社名[REDACTED_COMPANY_NAME]会社所在地              〒 812-0012[REDACTED_ADDRESS]電話番号[REDACTED_PHONE_NUMBER]次の労働条件によって雇用契約を締結します。   雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無     更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所     本社 (上記所在地)仕事の内容     産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日    所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇        年次有給 (法定) 特別休暇 (慶事 3 日有給)退職        定年 60 歳継続雇用 65 蔵までその他は就業規則による金額                月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率          時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                  2596締切・支払     毎月末日締切翌月 25 日支払 (口座振込)その他       社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
#   WARNING: Expected 4 fields but removed 3, ['address', 'company_name', 'phone_number'] on tesseract_Redactor_sample_0004.txt
# tesseract_Redactor_sample_0007.txt
# {'full_name': 'ダニエル・リベラスカイネット', 'company_name': 'ダニエル・リベラスカイネット・ロジスティクス', 'address': '大深町 3-1 グランフロント大阪06-6372-6790 大阪府大阪市北区', 'phone_number': '06-6372-6790', 'person_names': ['ダニエル・リベラスカイネット', '自身の会社名'], 'company_names': ['ダニエル・リベラスカイネット・ロジスティクス', '自身の会社名']}
# ['company_name', 'phone_number']
# original
# --- Page 1 ---
# 氏名 (フルネーム)会社名会社所在地電話番号 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)ダニエル・リベラスカイネット・ロジスティクス〒 530-0011 大阪府大阪市北区大深町 3-1 グランフロント大阪06-6372-6790次の労働条件によって雇用契約を締結します。雇用期間更新の有無試用期間就業の場所仕事の内容各業時間時間外・休日休日休暇退職金額割増率貞金締切・支払その他V期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新する場合があり得る (基準 : 業務量/成績・態度能カプ経営状況進捗)令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日本社 (上記所在地)産業機械の組立補助・検査・付随事務始業 9.00 終業 18:00 休憩 12:00て13:00所定時間外有 (約 20 時間/月) 休日労働無土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日年次有給 (法定) 特別休暇 (慶事 3 日有給)定年 60 蔵ノ継続雇用 65 歳までその他は就業規則による月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜25%毎月末日締切翌月 25 日支払 (口座振込)社会保険・雇用保険・労災保険加入  使用者 : 代表取締役早稲田太郎           ⑧ (会社名・所在地は上記のとおり)
#
# no pii
# --- Page 1 ---
# 氏名 (フルネーム)会社名会社所在地電話番号 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)[REDACTED_COMPANY_NAME]〒 530-0011 大阪府大阪市北区大深町 3-1 グランフロント大阪[REDACTED_PHONE_NUMBER]次の労働条件によって雇用契約を締結します。雇用期間更新の有無試用期間就業の場所仕事の内容各業時間時間外・休日休日休暇退職金額割増率貞金締切・支払その他V期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新する場合があり得る (基準 : 業務量/成績・態度能カプ経営状況進捗)令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日本社 (上記所在地)産業機械の組立補助・検査・付随事務始業 9.00 終業 18:00 休憩 12:00て13:00所定時間外有 (約 20 時間/月) 休日労働無土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日年次有給 (法定) 特別休暇 (慶事 3 日有給)定年 60 蔵ノ継続雇用 65 歳までその他は就業規則による月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜25%毎月末日締切翌月 25 日支払 (口座振込)社会保険・雇用保険・労災保険加入  使用者 : 代表取締役早稲田太郎           ⑧ (会社名・所在地は上記のとおり)
#
#   WARNING: Expected 4 fields but removed 2, ['company_name', 'phone_number'] on tesseract_Redactor_sample_0007.txt
# tesseract_Redactor_sample_0008.txt
# {'氏名': 'イワン・ポポフ', '会社名': '株式会社アース・クリエイト', '住所': '福岡県福岡市博多区博多駅中央街 1-1 JR 博多シティ', '電話番号': '092-475-8001'}
# []
# original
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム) イワン・ポポフ会社名             株式会社アース・クリエイト会社所在地            〒 812-0012 福岡県福岡市博多区博多駅中央街 1-1 JR 博多シティ電話番号            092-475-8001次の労働条件によって雇用契約を締結します。   雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無     更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所     本社 (上記所在地)仕事の内容     産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日    所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇        年次有給 (法定) 特別休暇 (慶事 3 日有給)退職        定年 60 歳継続雇用 65 蔵までその他は就業規則による金額        月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率       時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                    2596締切・支払     毎月末日締切翌月 25 日支払 (口座振込)その他       社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
# no pii
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム) イワン・ポポフ会社名             株式会社アース・クリエイト会社所在地            〒 812-0012 福岡県福岡市博多区博多駅中央街 1-1 JR 博多シティ電話番号            092-475-8001次の労働条件によって雇用契約を締結します。   雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無     更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所     本社 (上記所在地)仕事の内容     産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日    所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇        年次有給 (法定) 特別休暇 (慶事 3 日有給)退職        定年 60 歳継続雇用 65 蔵までその他は就業規則による金額        月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率       時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                    2596締切・支払     毎月末日締切翌月 25 日支払 (口座振込)その他       社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
#   WARNING: Expected 4 fields but removed 0, [] on tesseract_Redactor_sample_0008.txt
# tesseract_Redactor_sample_0009.txt
# {'氏名': 'オリビア・マーティン', '会社名': 'ホライズン・コンサルティング', '住所': '東京都港区六本木 6-10-1 六本木ヒルズ森タワー', '電話番号': '03-6406-6000', '身分情報': {'生年月日': '1998-05-10', '性別': '女性', '血液型': 'A', '顔写真': '写真', '身分証明書番号': '123456789', '住所': '東京都港区六本木 6-10-1 六本木ヒルズ森タワー'}}
# []
# original
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム) オリビア・マーティン会社名       ホライズン・コンサルティング会社所在地             〒 106-6150 東京都港区六本木 6-10-1 六本木ヒ ルズ森タワー電話番号               03-6406-6000 次の労働条件によって雇用契約を締結します。  雇用期間      期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無     更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間      令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所     本社 (上記所在地)仕事の内容     産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日    所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇        年次有給 (法定) 特別休暇 (慶事 3 日有給)退職        定年 60 歳継続雇用 65 蔵までその他は就業規則による金額        月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率       時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                  2596締切・支払     毎月末日締切翌月 25 日支払 (口座振込)その他       社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
# no pii
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム) オリビア・マーティン会社名       ホライズン・コンサルティング会社所在地             〒 106-6150 東京都港区六本木 6-10-1 六本木ヒ ルズ森タワー電話番号               03-6406-6000 次の労働条件によって雇用契約を締結します。  雇用期間      期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無     更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間      令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所     本社 (上記所在地)仕事の内容     産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日    所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇        年次有給 (法定) 特別休暇 (慶事 3 日有給)退職        定年 60 歳継続雇用 65 蔵までその他は就業規則による金額        月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率       時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                  2596締切・支払     毎月末日締切翌月 25 日支払 (口座振込)その他       社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
#   WARNING: Expected 4 fields but removed 0, [] on tesseract_Redactor_sample_0009.txt
# tesseract_Redactor_sample_0010.txt
# {'full_name': 'ファティマ・アリ', 'company_name': 'パシフィック・ゲダゲートウェイ会社', 'address': '兵庫県神戸市中央区東川崎町 1-6-1 神戸ハーバーランド, 郵便番号 650-0044', 'phone_number': '078-382-7100'}
# ['company_name', 'full_name', 'phone_number']
# original
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム) ファティマ・アリ 会社名         パシフィック・ゲダゲートウェイ会社所在地            〒 650-0044 兵庫県神戸市中央区東川崎町 1-6-1 神戸ハーバーランド umie電話番号              078-382-7100次の労働条件によって雇用契約を締結します。   雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無           更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所       本社 (上記所在地)仕事の内容          産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日        所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇            年次有給 (法定) 特別休暇 (慶事 3 日有給)退職                     定年 60 歳継続雇用 65 蔵までその他は就業規則による金額                月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率          時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                     2596締切・支払         毎月末日締切翌月 25 日支払 (口座振込)その他                     社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
# no pii
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム)[REDACTED_FULL_NAME] 会社名[REDACTED_COMPANY_NAME]所在地            〒 650-0044 兵庫県神戸市中央区東川崎町 1-6-1 神戸ハーバーランド umie電話番号[REDACTED_PHONE_NUMBER]次の労働条件によって雇用契約を締結します。   雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無           更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所       本社 (上記所在地)仕事の内容          産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日        所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇            年次有給 (法定) 特別休暇 (慶事 3 日有給)退職                     定年 60 歳継続雇用 65 蔵までその他は就業規則による金額                月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率          時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                     2596締切・支払         毎月末日締切翌月 25 日支払 (口座振込)その他                     社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
#   WARNING: Expected 4 fields but removed 3, ['company_name', 'full_name', 'phone_number'] on tesseract_Redactor_sample_0010.txt
# tesseract_Redactor_sample_0013.txt
# {'氏名': 'ムハンマド・イクバル', '会社名': '株式会社コスモ企画会社', '住所': '東京都新宿区西新宿 6-5-1 新宿アイランドタワー', '電話番号': '03-3348-1111'}
# []
# original
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム)    ムハンマド・イクバル 会社名                           株式会社コスモ企画会社所在地             〒 160-0023 東京都新宿区西新宿 6-5-1 新宿アイランドタワー電話番号                03-3348-1111次の労働条件によって雇用契約を締結します。   雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無           更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所       本社 (上記所在地)仕事の内容          産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日        所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇            年次有給 (法定) 特別休暇 (慶事 3 日有給)退職                     定年 60 歳継続雇用 65 蔵までその他は就業規則による金額                月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率          時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                     2596締切・支払         毎月末日締切翌月 25 日支払 (口座振込)その他                     社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
# no pii
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム)    ムハンマド・イクバル 会社名                           株式会社コスモ企画会社所在地             〒 160-0023 東京都新宿区西新宿 6-5-1 新宿アイランドタワー電話番号                03-3348-1111次の労働条件によって雇用契約を締結します。   雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無           更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所       本社 (上記所在地)仕事の内容          産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日        所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇            年次有給 (法定) 特別休暇 (慶事 3 日有給)退職                     定年 60 歳継続雇用 65 蔵までその他は就業規則による金額                月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率          時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                     2596締切・支払         毎月末日締切翌月 25 日支払 (口座振込)その他                     社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
#   WARNING: Expected 4 fields but removed 0, [] on tesseract_Redactor_sample_0013.txt
# tesseract_Redactor_sample_0014.txt
# {'full_name': 'クロエ', 'company_name': 'クロエ・ルコント', 'address': '052-527-8888', 'phone_number': '052-527-8888', 'personal_info': {'name': 'クロエ', 'company': 'クロエ・ルコント会社名', 'phone': '052-527-8888'}}
# ['address', 'company_name']
# original
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム)   クロエ・ルコント会社名           アクアソリューションズ合同会社会社所在地            〒 450-6201 愛知県名古屋市中村区名駅 4.7-1 ミッドランドスクエア電話番号               052-527-8888次の労働条件によって雇用契約を締結します。   雇用期間      期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無     更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間      令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所     本社 (上記所在地)仕事の内容     産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日    所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇        年次有給 (法定) 特別休暇 (慶事 3 日有給)退職        定年 60 歳継続雇用 65 蔵までその他は就業規則による金額        月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率       時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                  2596締切・支払     毎月末日締切翌月 25 日支払 (口座振込)その他       社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
# no pii
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム)[REDACTED_COMPANY_NAME]会社名           アクアソリューションズ合同会社会社所在地            〒 450-6201 愛知県名古屋市中村区名駅 4.7-1 ミッドランドスクエア電話番号[REDACTED_ADDRESS]次の労働条件によって雇用契約を締結します。   雇用期間      期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無     更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間      令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所     本社 (上記所在地)仕事の内容     産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日    所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇        年次有給 (法定) 特別休暇 (慶事 3 日有給)退職        定年 60 歳継続雇用 65 蔵までその他は就業規則による金額        月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率       時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                  2596締切・支払     毎月末日締切翌月 25 日支払 (口座振込)その他       社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
#   WARNING: Expected 4 fields but removed 2, ['address', 'company_name'] on tesseract_Redactor_sample_0014.txt
# tesseract_Redactor_sample_0016.txt
# {'full_name': 'ユリア・ノビコワ', 'company_name': 'アクアソリューションズ合同会社会社', 'address': '愛知県名古屋市中村区名駅 4-7-1 ミッドランドスクエア', 'phone_number': '052-527-8889'}
# ['company_name', 'full_name', 'phone_number']
# original
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム) ユリア・ノビコワ会社名           アクアソリューションズ合同会社会社所在地            〒 450-6201 愛知県名古屋市中村区名駅 4.7-1 ミッドランドスクエア電話番号               052-527-8889 次の労働条件によって雇用契約を締結します。  雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無           更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所       本社 (上記所在地)仕事の内容          産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日        所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇            年次有給 (法定) 特別休暇 (慶事 3 日有給)退職                     定年 60 歳継続雇用 65 蔵までその他は就業規則による金額                月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率          時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                     2596締切・支払         毎月末日締切翌月 25 日支払 (口座振込)その他                     社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
# no pii
# --- Page 1 ---
# 令和 7 年 10 月 11 日労働条件通知書兼雇用契約書 (シンプル)氏名 (フルネーム)[REDACTED_FULL_NAME]会社名[REDACTED_COMPANY_NAME]所在地            〒 450-6201 愛知県名古屋市中村区名駅 4.7-1 ミッドランドスクエア電話番号[REDACTED_PHONE_NUMBER] 次の労働条件によって雇用契約を締結します。  雇用期間         期間の定めあり (令和7 年 11 月 1 日一令和 8 年 10 月 31 日)更新の有無           更新する場合があり得る (基準 : 業務量/成績・態度/能カノ経営状況進捗)試用期間         令和 7 年 11 月 1 日ー令和 8 年 1 月 31 日就業の場所       本社 (上記所在地)仕事の内容          産業機械の組立補助・検査・付随事務各業時間            始業 9.00 終業 18:00 休憩 12:00て13:00時間外・休日        所定時間外有 (約 20 時間プ月) 休日労働無休日              土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日休暇            年次有給 (法定) 特別休暇 (慶事 3 日有給)退職                     定年 60 歳継続雇用 65 蔵までその他は就業規則による金額                月給 320.000 円、役職手当 10.000 円、通勤手当実費 (上限 30.000 円)割増率          時間外 (法定超月 60h 以内) 25%/ (60h 超) 50%%、休日 (法定) 35%、深夜賃金                     2596締切・支払         毎月末日締切翌月 25 日支払 (口座振込)その他                     社会保険・雇用保険・労災保険加入使用者 : 代表取締役早稲田太郎                               ⑧ (会社名・所在地は上記のとおり)
#
#   WARNING: Expected 4 fields but removed 3, ['company_name', 'full_name', 'phone_number'] on tesseract_Redactor_sample_0016.txt
# tesseract_Redactor_sample_0018.txt
# {'full_name': '山田 優子', 'company_name': '雪雇用契約書（株式会社ミナト電機）', 'address': '神奈川県横浜市中区新港 1-3-1 横浜赤レンガ倉庫045-211-1555', 'phone_number': '045-211-1555'}
# ['address', 'full_name']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号山田優子株式会社ミナト電機〒 231-0001 神奈川県横浜市中区新港 1-3-1 横浜赤レンガ倉庫045-211-1555   契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号[REDACTED_FULL_NAME]株式会社ミナト電機〒 231-0001[REDACTED_ADDRESS]   契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 2, ['address', 'full_name'] on tesseract_Redactor_sample_0018.txt
# tesseract_Redactor_sample_0019.txt
# {'full_name': '木下拓海', 'company_name': '関西スチール株式会社', 'address': '大阪府大阪市中央区難波 5-1.60 なんばパークス06', 'phone_number': '06-6644-7100'}
# ['address', 'company_name', 'full_name']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号木下拓海関西スチール株式会社〒 542-0076 大阪府大阪市中央区難波 5-1.60 なんばパークス06-6644-7100 契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号[REDACTED_FULL_NAME][REDACTED_COMPANY_NAME]〒 542-0076[REDACTED_ADDRESS]-6644-7100 契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 3, ['address', 'company_name', 'full_name'] on tesseract_Redactor_sample_0019.txt
# tesseract_Redactor_sample_0021.txt
# {'full_name': '池田 蓮日', 'company_name': '出製作所', 'address': '東京都墨田区押上 1-1-2 池田蓮日出製作所', 'phone_number': '131-8634'}
# ['company_name', 'full_name', 'phone_number']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号池田蓮日の出製作所〒 131-8634 東京都墨田区押上 1-1-2 東京スカイツリーイーストタワー03-5809-5051 契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号[REDACTED_FULL_NAME]の[REDACTED_COMPANY_NAME]〒[REDACTED_PHONE_NUMBER] 東京都墨田区押上 1-1-2 東京スカイツリーイーストタワー03-5809-5051 契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 3, ['company_name', 'full_name', 'phone_number'] on tesseract_Redactor_sample_0021.txt
# tesseract_Redactor_sample_0023.txt
# {'full_name': '石川 大地', 'company_name': '関西スチール株式会社', 'address': '大阪府大阪市中央区難波 5-1.60 なんばパークス06', 'phone_number': '06-6644-7102'}
# ['address', 'company_name', 'full_name']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号石川大地関西スチール株式会社〒 542-0076 大阪府大阪市中央区難波 5-1.60 なんばパークス06-6644-7102 契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号[REDACTED_FULL_NAME][REDACTED_COMPANY_NAME]〒 542-0076[REDACTED_ADDRESS]-6644-7102 契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 3, ['address', 'company_name', 'full_name'] on tesseract_Redactor_sample_0023.txt
# tesseract_Redactor_sample_0024.txt
# {'full_name': '結衣 清水', 'company_name': '中部ファインテック', 'address': '愛知県名古屋市中区栄 3-5-1 名古屋三越', 'phone_number': '052-252-1113'}
# ['address', 'company_name', 'phone_number']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号清水結衣中部ファインテック〒 460-0008 愛知県名古屋市中区栄 3-5-1 名古屋三越052-252-1113契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号清水結衣[REDACTED_COMPANY_NAME]〒 460-0008[REDACTED_ADDRESS][REDACTED_PHONE_NUMBER]契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 3, ['address', 'company_name', 'phone_number'] on tesseract_Redactor_sample_0024.txt
# tesseract_Redactor_sample_0025.txt
# {'full_name': '前田 悠斗', 'company_name': '雪雇用契約書', 'address': '東京都江東区豊洲 135-8625', 'phone_number': '03-6910-1234'}
# ['company_name', 'full_name', 'phone_number']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号前田悠斗株式会社サンライズ物流〒 135-8625 東京都江東区豊洲 2.4.9 アーバンドックららぼーと豊洲03-6910-1234契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書[REDACTED_COMPANY_NAME] (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号[REDACTED_FULL_NAME]株式会社サンライズ物流〒 135-8625 東京都江東区豊洲 2.4.9 アーバンドックららぼーと豊洲[REDACTED_PHONE_NUMBER]契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 3, ['company_name', 'full_name', 'phone_number'] on tesseract_Redactor_sample_0025.txt
# tesseract_Redactor_sample_0026.txt
# {'full_name': "朋井 菜々 (Poin' Ii Nana)", 'company_name': 'サクラ精客機器 (Sakura Seikokku Kigen)', 'address': '埼玉県さいたま市大宮区桜木町 330-9555', 'phone_number': '048-647-4111'}
# ['phone_number']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号朋井菜々サクラ精客機器〒 330-9555 埼玉県さいたま市大宮区桜木町 1.7.5 ソニックシティビル048-647-4111契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号朋井菜々サクラ精客機器〒 330-9555 埼玉県さいたま市大宮区桜木町 1.7.5 ソニックシティビル[REDACTED_PHONE_NUMBER]契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 1, ['phone_number'] on tesseract_Redactor_sample_0026.txt
# tesseract_Redactor_sample_0027.txt
# {'full_name': '岡田 航', 'company_name': 'サンライズ物流', 'address': '東京都江東区豊洲 135-8625', 'phone_number': '03-6910-1235'}
# ['company_name', 'full_name', 'phone_number']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号岡田航株式会社サンライズ物流〒 135-8625 東京都江東区豊洲 2.4.9 アーバンドックららぼーと豊洲03-6910-1235契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号[REDACTED_FULL_NAME]株式会社[REDACTED_COMPANY_NAME]〒 135-8625 東京都江東区豊洲 2.4.9 アーバンドックららぼーと豊洲[REDACTED_PHONE_NUMBER]契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 3, ['company_name', 'full_name', 'phone_number'] on tesseract_Redactor_sample_0027.txt
# tesseract_Redactor_sample_0028.txt
# {'full_name': '後藤 美', 'company_name': 'サクラ精密機器会社', 'address': '埼玉県さいたま市大宮区桜木町 1-7-5 ソニックシティビル', 'phone_number': '048-647-4112'}
# ['company_name', 'full_name', 'phone_number']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書兼雇用契約書 (20141125 形式)氏名 (フルネーム) 後藤美会社名                    サクラ精密機器会社所在地              〒 330-9555 埼玉県さいたま市大宮区桜木町 1.7.5 ソニックシティビル電話番号               048-647-4112契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の試用期間 : 3 か月性あり (判断基準 : 業務量・成績・能力・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 :9:00 て18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金語手当間増賃金率締切・支反控除見給・1MI由漆与・退職 : 定年 60 蔵ノ継続雇用 65 歳まで自己都合 : 30 日前届雇用相談窓口 : 人事総務部 (TEL : 記載済み) 月給 330,000 円通勤実費 (上限 30.000 円)、住宅手当 10.000 円法定超 25%、法定休日 35%、深夜 259%、月 60h 超 50%締切 : 毎月末日支払 : 翌月 25 日 (口座振込)有 (税金・社会保険・雇用保険)退職金 昇給:年1回賞与:年2 回退職金 :無出/解雇 : 各業規則
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書兼雇用契約書 (20141125 形式)氏名 (フルネーム)[REDACTED_FULL_NAME]会社名[REDACTED_COMPANY_NAME]所在地              〒 330-9555 埼玉県さいたま市大宮区桜木町 1.7.5 ソニックシティビル電話番号[REDACTED_PHONE_NUMBER]契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の試用期間 : 3 か月性あり (判断基準 : 業務量・成績・能力・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 :9:00 て18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金語手当間増賃金率締切・支反控除見給・1MI由漆与・退職 : 定年 60 蔵ノ継続雇用 65 歳まで自己都合 : 30 日前届雇用相談窓口 : 人事総務部 (TEL : 記載済み) 月給 330,000 円通勤実費 (上限 30.000 円)、住宅手当 10.000 円法定超 25%、法定休日 35%、深夜 259%、月 60h 超 50%締切 : 毎月末日支払 : 翌月 25 日 (口座振込)有 (税金・社会保険・雇用保険)退職金 昇給:年1回賞与:年2 回退職金 :無出/解雇 : 各業規則
#
#   WARNING: Expected 4 fields but removed 3, ['company_name', 'full_name', 'phone_number'] on tesseract_Redactor_sample_0028.txt
# tesseract_Redactor_sample_0029.txt
# {'氏名': '村上太', '会社名': 'フロンティア・エージェンシー', '住所': '東京都渋谷区渋谷 2-24-12 渋谷スクランブルスクエア03-4221-4280', '電話番号': '03-4221-4280', '業種': '産業用ロボット', '勤務時間': '9:00 - 18:00（休憩60分）', '休日': '土曜日、日曜日、祝日、年末年始（12月29日から1月3日）', '年次休暇': '年間120日（年休法定、初年度10日）'}
# []
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号村上太フロンティア・エージェンシー〒 150-0002 東京都渋谷区渋谷 2-24-12 渋谷スクランブルスクエア03-4221-4280契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号村上太フロンティア・エージェンシー〒 150-0002 東京都渋谷区渋谷 2-24-12 渋谷スクランブルスクエア03-4221-4280契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 0, [] on tesseract_Redactor_sample_0029.txt
# tesseract_Redactor_sample_0030.txt
# {'full_name': '長谷川 里子', 'company_name': '京葉 エンジニアリング', 'address': '千葉県千葉市美浜区中瀬 2-6-1 WBG マリブウエスト', 'phone_number': '043-297-3000'}
# ['company_name', 'phone_number']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号長谷川莉子株式会社京葉エンジニアリング〒 261-7132 千葉県千葉市美浜区中瀬 2.6-1 WBG マリブウエスト043-297-3000契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号長谷川莉子株式会社[REDACTED_COMPANY_NAME]〒 261-7132 千葉県千葉市美浜区中瀬 2.6-1 WBG マリブウエスト[REDACTED_PHONE_NUMBER]契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 2, ['company_name', 'phone_number'] on tesseract_Redactor_sample_0030.txt
# tesseract_Redactor_sample_0031.txt
# {'full_name': '西村 陽菜', 'company_name': 'フロンティア・エージェンシー', 'address': '東京都渋谷区渋谷 2-24-12 渋谷スクランブルスクエア03-4221-4281', 'phone_number': '03-4221-4281'}
# ['address', 'company_name', 'full_name']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号 西村陽菜フロンティア・エージェンシー〒 150-0002 東京都渋谷区渋谷 2-24-12 渋谷スクランブルスクエア03-4221-4281契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号[REDACTED_FULL_NAME][REDACTED_COMPANY_NAME]〒 150-0002[REDACTED_ADDRESS]契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金              月給 330.000 円諸手当              通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 割増賃金率           法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払         締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除                有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 3, ['address', 'company_name', 'full_name'] on tesseract_Redactor_sample_0031.txt
# tesseract_Redactor_sample_0032.txt
# {'full_name': '石井 涼介', 'company_name': '京葉エンジニアリング', 'address': '千葉県千葉市美浜区中瀬 2.6-1 WBG マリブウエスト 043-297-3001', 'phone_number': '043-297-3001'}
# ['address', 'company_name', 'full_name']
# original
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号石井涼介株式会社京葉エンジニアリング〒 261-7132 千葉県千葉市美浜区中瀬 2.6-1 WBG マリブウエスト043-297-3001契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
# no pii
# --- Page 1 ---
# (契約締結年月日) 、令和 7年10月11日労働条件通知書雪雇用契約書 (20141125 形式)氏名 (フルネーム)会社名会社所在地電話番号[REDACTED_FULL_NAME]株式会社[REDACTED_COMPANY_NAME]〒 261-7132[REDACTED_ADDRESS]契約期間 期間の定め無し (雇入日:令和7年11月1日)更新の有無 : 更新の可能性あり (判断基準 : 業務量・成績・能力試用期間 : 3 か月・経営状況・進捗)就業の場所 : 本社 (上記所在地) 将来、拠点異動の可能性あり従事すべき業務 : 産業用ロボットの組立・検査・工程改善補助始業・終業・休憩 : 9.00 18:00 (休憩 60 分)休日 : 土・日・祝・年末年始 (12/29一1/3) 年間 120 日休暇 : 年休法定 (初年度 10 日) 継続勤務 6 か月以内の年休有基本賃金      月給 330.000 円諸手当 通勤実費 (上限 30.000 円)、住宅手当 10,000 円人 少條金率     法定超 259%、法定休日 35%、深夜 259%%、月 60h 超 50%_ 締切・支払     締切 : 毎月末日支払 : 翌月 25 日 (日座振込)控除        有 (税金・社会保険・雇用保険)昇給・賞与・退職金 昇給:年1 回賞与 : 年 2 回ノ退職金 : 無退職 : 定年 60 歳継続雇用 65 歳まで/自己都合 : 30 日前届出/解雇 : 就業規則雇用相談窓口 : 人事総務部 (TEL : 記載済み)
#
#   WARNING: Expected 4 fields but removed 3, ['address', 'company_name', 'full_name'] on tesseract_Redactor_sample_0032.txt
# tesseract_Redactor_sample_0036.txt
# {'full_name': '大塚さくら', 'company_name': '大塚さくら 株式会社ネオ・コーポレーション', 'address': '北海道札幌市中央区北5条西2.5 JRタワー', 'phone_number': '011-209-5100'}
# ['address', 'full_name', 'phone_number']
# original
# --- Page 1 ---
# 労働条件通知書替雇用契約書 (jE社員 2023) 氏名 (フルネーム)      大塚さくら会社名          株式会社ネオ・コーポレーション会社所在地                  〒 060-0005 北海道札幌市中央区北 5 条西 2.5 JR タワー電話番号                    011-209-5100契約期間 正社員 (期間の定めなし)試用期間 : 令和 7 年 11 月 1 日一令和 8 年 1 月 31 日 (最長 1 か月延長の可能性あり)就業の場所 (入社時) : 本社 (上記所在地) 変更の範囲 : 各拠点・プロジェクト先業務の内容 (入社時) : 産業用ロボットの組立・検査・工程改善補助変更の範囲 : 会社の定める関連業務役職: アノソシエイトエンジニア勤務時間・体憩 : 10:00 て19:00 (休憩 60 分) プフレックス (コア 11:00一16:00)休日・休暇 : 土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日年休 : 法定 (入社6 か月後10 日) /特別休暇 (慶事 3 日)基本給                   月給 350.000 円 (試用期間中 330.000 円)内訳                  基本給 320.000 円、役職手当 10.000 円、職務手当 10.000 円、通勤実費(上限 30,000 円)時間外                   有 (平均 15一25 時間ノ月)賃金割増率                       時間外 25%プ 60h 超 509%/所定超 25%ン休日 (法定) 35%ン深夜 25%締切・支払             毎月末日締翌月 25 日支払い (休日は前営業日)改定                      有 (年 1 回、評価により)賞与・退職金          賞与 : 年 2 回ノ退職金 : 舞保険等                   雇用・社会・労災加入退職 : 定年 60 蔵/継続雇用 65 上蔵まで/自己都合 :1 ヶ月前届出解雇 : 各業規則就業規則 : 社内ポータル人事総務部
#
# no pii
# --- Page 1 ---
# 労働条件通知書替雇用契約書 (jE社員 2023) 氏名 (フルネーム)[REDACTED_FULL_NAME]会社名          株式会社ネオ・コーポレーション会社所在地                  〒 060-0005[REDACTED_ADDRESS]電話番号[REDACTED_PHONE_NUMBER]契約期間 正社員 (期間の定めなし)試用期間 : 令和 7 年 11 月 1 日一令和 8 年 1 月 31 日 (最長 1 か月延長の可能性あり)就業の場所 (入社時) : 本社 (上記所在地) 変更の範囲 : 各拠点・プロジェクト先業務の内容 (入社時) : 産業用ロボットの組立・検査・工程改善補助変更の範囲 : 会社の定める関連業務役職: アノソシエイトエンジニア勤務時間・体憩 : 10:00 て19:00 (休憩 60 分) プフレックス (コア 11:00一16:00)休日・休暇 : 土曜・日曜・祝日・年末年始 (12/29一1/3) 年間 120 日年休 : 法定 (入社6 か月後10 日) /特別休暇 (慶事 3 日)基本給                   月給 350.000 円 (試用期間中 330.000 円)内訳                  基本給 320.000 円、役職手当 10.000 円、職務手当 10.000 円、通勤実費(上限 30,000 円)時間外                   有 (平均 15一25 時間ノ月)賃金割増率                       時間外 25%プ 60h 超 509%/所定超 25%ン休日 (法定) 35%ン深夜 25%締切・支払             毎月末日締翌月 25 日支払い (休日は前営業日)改定                      有 (年 1 回、評価により)賞与・退職金          賞与 : 年 2 回ノ退職金 : 舞保険等                   雇用・社会・労災加入退職 : 定年 60 蔵/継続雇用 65 上蔵まで/自己都合 :1 ヶ月前届出解雇 : 各業規則就業規則 : 社内ポータル人事総務部
#
#   WARNING: Expected 4 fields but removed 3, ['address', 'full_name', 'phone_number'] on tesseract_Redactor_sample_0036.txt
# 23

# %%
txt_folder = '../data/unstructured_pii/'

# %%
import pandas as pd
import glob
import os


def normalize(txt):
    txt = txt.replace(' ', '').replace('\n', '')
    txt = txt.replace('〒','')
    return txt

master_labels_fn = '../data/data_generation/master_label.csv'

# Read master labels
master_labels = pd.read_csv(master_labels_fn)
print("Master Labels:")
print(master_labels)
print("\n" + "="*80 + "\n")

# Get all txt files
txt_files = glob.glob(txt_folder + '*.txt')
txt_files = sorted(txt_files)

# Columns to check (excluding file_name and template_id)
columns_to_check = ['full_name', 'company_name', 'company_address', 'phone_number']

# Results storage
results = []

for txt_file in txt_files:
    txt_filename = os.path.basename(txt_file)
    
    # Extract base filename (e.g., "Redactor_sample_0001" from "paddle_Redactor_sample_0001.txt")
    # This handles both tesseract_ and paddle_ prefixes
    base_name = txt_filename.replace('paddle_', '').replace('tesseract_', '').replace('.txt', '')
    
    # Find corresponding row in master_labels
    label_row = master_labels[master_labels['file_name'] == base_name]
    
    if label_row.empty:
        print(f"Warning: No labels found for {base_name}")
        continue
    
    # Read txt file content
    with open(txt_file, 'r', encoding='utf-8') as f:
        txt_content = f.read()
    
    # Remove spaces and newlines for better matching
    txt_content_normalized = normalize(txt_content)
    
    
    print(f"Evaluating: {txt_filename}")
    print(f"Base name: {base_name}")
    
    # Check each column
    found_count = 0
    total_count = 0
    column_results = {}
    
    for col in columns_to_check:
        label_value = str(label_row[col].values[0])
        if pd.notna(label_value) and label_value != 'nan':
            total_count += 1
            # Normalize label value (remove spaces)
            label_normalized = normalize(label_value)
            
            # Check if label is in txt content
            if label_normalized in txt_content_normalized:
                found_count += 1
                column_results[col] = 'FOUND'
                print(f"  ✓ {col}: '{label_value}' - FOUND")
            else:
                column_results[col] = 'NOT FOUND'
                print(f"  ✗ {col}: '{label_value}' - NOT FOUND")
        else:
            column_results[col] = 'N/A'
    
    # Calculate percentage
    percentage = (found_count / total_count * 100) if total_count > 0 else 0
    
    print(f"  → Found: {found_count}/{total_count} ({percentage:.1f}%)")
    print()
    
    # Store results
    result_dict = {
        'txt_file': txt_filename,
        'base_name': base_name,
        'found': found_count,
        'total': total_count,
        'percentage': percentage
    }
    result_dict.update(column_results)
    results.append(result_dict)

# Create results DataFrame
results_df = pd.DataFrame(results)
print("\n" + "="*80)
print("SUMMARY OF RESULTS:")
print("="*80)
print(results_df[['txt_file', 'found', 'total', 'percentage']])

print("\n" + "="*80)
print("DETAILED RESULTS BY COLUMN:")
print("="*80)
print(results_df)

# Save results to CSV
output_file = '../data/ocr_evaluation_results.csv'
results_df.to_csv(output_file, index=False)
print(f"\nResults saved to: {output_file}")
# Out:
# Master Labels:
#                file_name  full_name    company_name  \
# 0   Redactor_sample_0001   ソフィア・ミラー   株式会社オリオンシステムズ
# 1   Redactor_sample_0002   キム・ミンジュン      ネクサス貿易合同会社
# 2   Redactor_sample_0003  エミリー・ブラウン  スカイネット・ロジスティクス
# 3   Redactor_sample_0004    チャン・ウェイ   株式会社アース・クリエイト
# 4   Redactor_sample_0005   ルイス・カルロス   株式会社オリオンシステムズ
# ..                   ...        ...             ...
# 59  Redactor_sample_0060      野村 美穂        リバーサイド工業
# 60  Redactor_sample_0061      古川 幸助    株式会社アルファドライブ
# 61  Redactor_sample_0062       菊地 栞       合同会社サンセット
# 62  Redactor_sample_0063      千葉 雄大    株式会社アルファドライブ
# 63  Redactor_sample_0064      上野 莉奈       合同会社サンセット
#
#                                company_address  phone_number  template_id
# 0      〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ  03-6262-1212            1
# 1   〒220-0012 神奈川県横浜市西区みなとみらい2-2-1 横浜ランドマークタワー  045-222-5501            1
# 2           〒530-0011 大阪府大阪市北区大深町3-1 グランフロント大阪  06-6372-6789            1
# 3         〒812-0012 福岡県福岡市博多区博多駅中央街1-1 JR博多シティ  092-475-8000            1
# 4      〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ  03-6262-1213            1
# ..                                         ...           ...          ...
# 59    〒950-0088 新潟県新潟市中央区万代1-6-1 万代シテイバスセンタービル  025-246-6112            4
# 60              〒108-0073 東京都港区三田1-4-28 三田国際ビル  03-3452-1111            4
# 61            〒900-0015 沖縄県那覇市久茂地1-1-1 パレットくもじ  098-867-1171            4
# 62              〒108-0073 東京都港区三田1-4-28 三田国際ビル  03-3452-1113            4
# 63            〒900-0015 沖縄県那覇市久茂地1-1-1 パレットくもじ  098-867-1172            4
#
# [64 rows x 6 columns]
#
# ================================================================================
#
# Evaluating: paddle_Redactor_sample_0001.txt
# Base name: Redactor_sample_0001
#   ✓ full_name: 'ソフィア・ミラー' - FOUND
#   ✓ company_name: '株式会社オリオンシステムズ' - FOUND
#   ✗ company_address: '〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ' - NOT FOUND
#   ✓ phone_number: '03-6262-1212' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0002.txt
# Base name: Redactor_sample_0002
#   ✓ full_name: 'キム・ミンジュン' - FOUND
#   ✗ company_name: 'ネクサス貿易合同会社' - NOT FOUND
#   ✗ company_address: '〒220-0012 神奈川県横浜市西区みなとみらい2-2-1 横浜ランドマークタワー' - NOT FOUND
#   ✓ phone_number: '045-222-5501' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0003.txt
# Base name: Redactor_sample_0003
#   ✓ full_name: 'エミリー・ブラウン' - FOUND
#   ✓ company_name: 'スカイネット・ロジスティクス' - FOUND
#   ✗ company_address: '〒530-0011 大阪府大阪市北区大深町3-1 グランフロント大阪' - NOT FOUND
#   ✓ phone_number: '06-6372-6789' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0004.txt
# Base name: Redactor_sample_0004
#   ✗ full_name: 'チャン・ウェイ' - NOT FOUND
#   ✓ company_name: '株式会社アース・クリエイト' - FOUND
#   ✗ company_address: '〒812-0012 福岡県福岡市博多区博多駅中央街1-1 JR博多シティ' - NOT FOUND
#   ✓ phone_number: '092-475-8000' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0005.txt
# Base name: Redactor_sample_0005
#   ✓ full_name: 'ルイス・カルロス' - FOUND
#   ✓ company_name: '株式会社オリオンシステムズ' - FOUND
#   ✗ company_address: '〒100-0004 東京都千代田区大手町1-9-2 大手町フィナンシャルシティ' - NOT FOUND
#   ✓ phone_number: '03-6262-1213' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0006.txt
# Base name: Redactor_sample_0006
#   ✓ full_name: 'アナ・ペレイラ' - FOUND
#   ✗ company_name: 'ネクサス貿易合同会社' - NOT FOUND
#   ✗ company_address: '〒220-0012 神奈川県横浜市西区みなとみらい2-2-1 横浜ランドマークタワー' - NOT FOUND
#   ✓ phone_number: '045-222-5502' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0007.txt
# Base name: Redactor_sample_0007
#   ✓ full_name: 'ダニエル・リベラ' - FOUND
#   ✓ company_name: 'スカイネット・ロジスティクス' - FOUND
#   ✗ company_address: '〒530-0011 大阪府大阪市北区大深町3-1 グランフロント大阪' - NOT FOUND
#   ✓ phone_number: '06-6372-6790' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0008.txt
# Base name: Redactor_sample_0008
#   ✓ full_name: 'イワン・ポポフ' - FOUND
#   ✓ company_name: '株式会社アース・クリエイト' - FOUND
#   ✗ company_address: '〒812-0012 福岡県福岡市博多区博多駅中央街1-1 JR博多シティ' - NOT FOUND
#   ✓ phone_number: '092-475-8001' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0009.txt
# Base name: Redactor_sample_0009
#   ✓ full_name: 'オリビア・マーティン' - FOUND
#   ✓ company_name: 'ホライズン・コンサルティング' - FOUND
#   ✗ company_address: '〒106-6150 東京都港区六本木6-10-1 六本木ヒルズ森タワー' - NOT FOUND
#   ✓ phone_number: '03-6406-6000' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0010.txt
# Base name: Redactor_sample_0010
#   ✓ full_name: 'ファティマ・アリ' - FOUND
#   ✓ company_name: 'パシフィック・ゲートウェイ' - FOUND
#   ✗ company_address: '〒650-0044 兵庫県神戸市中央区東川崎町1-6-1 神戸ハーバーランドumie' - NOT FOUND
#   ✓ phone_number: '078-382-7100' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0011.txt
# Base name: Redactor_sample_0011
#   ✓ full_name: 'アレクサンダー・シュミット' - FOUND
#   ✓ company_name: 'ホライズン・コンサルティング' - FOUND
#   ✓ company_address: '〒106-6150 東京都港区六本木6-10-1 六本木ヒルズ森タワー' - FOUND
#   ✓ phone_number: '03-6406-6001' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0012.txt
# Base name: Redactor_sample_0012
#   ✓ full_name: 'マリア・ゴンザレス' - FOUND
#   ✓ company_name: 'パシフィック・ゲートウェイ' - FOUND
#   ✗ company_address: '〒650-0044 兵庫県神戸市中央区東川崎町1-6-1 神戸ハーバーランドumie' - NOT FOUND
#   ✓ phone_number: '078-382-7101' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0013.txt
# Base name: Redactor_sample_0013
#   ✓ full_name: 'ムハンマド・イクバル' - FOUND
#   ✓ company_name: '株式会社コスモ企画' - FOUND
#   ✓ company_address: '〒160-0023 東京都新宿区西新宿6-5-1 新宿アイランドタワー' - FOUND
#   ✓ phone_number: '03-3348-1111' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0014.txt
# Base name: Redactor_sample_0014
#   ✓ full_name: 'クロエ・ルコント' - FOUND
#   ✓ company_name: 'アクアソリューションズ合同会社' - FOUND
#   ✗ company_address: '〒450-6201 愛知県名古屋市中村区名駅4-7-1 ミッドランドスクエア' - NOT FOUND
#   ✓ phone_number: '052-527-8888' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0015.txt
# Base name: Redactor_sample_0015
#   ✓ full_name: 'ラファエル・フェルナンデス' - FOUND
#   ✓ company_name: '株式会社コスモ企画' - FOUND
#   ✓ company_address: '〒160-0023 東京都新宿区西新宿6-5-1 新宿アイランドタワー' - FOUND
#   ✓ phone_number: '03-3348-1112' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0016.txt
# Base name: Redactor_sample_0016
#   ✓ full_name: 'ユリア・ノビコワ' - FOUND
#   ✓ company_name: 'アクアソリューションズ合同会社' - FOUND
#   ✗ company_address: '〒450-6201 愛知県名古屋市中村区名駅4-7-1 ミッドランドスクエア' - NOT FOUND
#   ✓ phone_number: '052-527-8889' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0017.txt
# Base name: Redactor_sample_0017
#   ✓ full_name: '佐々木 翔太' - FOUND
#   ✓ company_name: '日の出製作所' - FOUND
#   ✗ company_address: '〒131-8634 東京都墨田区押上1-1-2 東京スカイツリーイーストタワー' - NOT FOUND
#   ✓ phone_number: '03-5809-5050' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0018.txt
# Base name: Redactor_sample_0018
#   ✓ full_name: '山田 優子' - FOUND
#   ✓ company_name: '株式会社ミナト電機' - FOUND
#   ✗ company_address: '〒231-0001 神奈川県横浜市中区新港1-3-1 横浜赤レンガ倉庫' - NOT FOUND
#   ✓ phone_number: '045-211-1555' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0019.txt
# Base name: Redactor_sample_0019
#   ✓ full_name: '木下 拓海' - FOUND
#   ✗ company_name: '関西スチール株式会社' - NOT FOUND
#   ✗ company_address: '〒542-0076 大阪府大阪市中央区難波5-1-60 なんばパークス' - NOT FOUND
#   ✓ phone_number: '06-6644-7100' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0020.txt
# Base name: Redactor_sample_0020
#   ✓ full_name: '森 りん' - FOUND
#   ✗ company_name: '中部ファインテック' - NOT FOUND
#   ✗ company_address: '〒460-0008 愛知県名古屋市中区栄3-5-1 名古屋三越' - NOT FOUND
#   ✓ phone_number: '052-252-1111' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0021.txt
# Base name: Redactor_sample_0021
#   ✓ full_name: '池田 蓮' - FOUND
#   ✗ company_name: '日の出製作所' - NOT FOUND
#   ✗ company_address: '〒131-8634 東京都墨田区押上1-1-2 東京スカイツリーイーストタワー' - NOT FOUND
#   ✓ phone_number: '03-5809-5051' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0022.txt
# Base name: Redactor_sample_0022
#   ✓ full_name: '橋本 あかり' - FOUND
#   ✓ company_name: '株式会社ミナト電機' - FOUND
#   ✗ company_address: '〒231-0001 神奈川県横浜市中区新港1-3-1 横浜赤レンガ倉庫' - NOT FOUND
#   ✓ phone_number: '045-211-1556' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0023.txt
# Base name: Redactor_sample_0023
#   ✓ full_name: '石川 大地' - FOUND
#   ✗ company_name: '関西スチール株式会社' - NOT FOUND
#   ✗ company_address: '〒542-0076 大阪府大阪市中央区難波5-1-60 なんばパークス' - NOT FOUND
#   ✓ phone_number: '06-6644-7102' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0024.txt
# Base name: Redactor_sample_0024
#   ✓ full_name: '清水 結衣' - FOUND
#   ✓ company_name: '中部ファインテック' - FOUND
#   ✗ company_address: '〒460-0008 愛知県名古屋市中区栄3-5-1 名古屋三越' - NOT FOUND
#   ✓ phone_number: '052-252-1113' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0025.txt
# Base name: Redactor_sample_0025
#   ✓ full_name: '前田 悠斗' - FOUND
#   ✓ company_name: '株式会社サンライズ物流' - FOUND
#   ✓ company_address: '〒135-8625 東京都江東区豊洲2-4-9 アーバンドック ららぽーと豊洲' - FOUND
#   ✓ phone_number: '03-6910-1234' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0026.txt
# Base name: Redactor_sample_0026
#   ✓ full_name: '藤井 菜々' - FOUND
#   ✓ company_name: 'サクラ精密機器' - FOUND
#   ✗ company_address: '〒330-9555 埼玉県さいたま市大宮区桜木町1-7-5 ソニックシティビル' - NOT FOUND
#   ✓ phone_number: '048-647-4111' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0027.txt
# Base name: Redactor_sample_0027
#   ✓ full_name: '岡田 航' - FOUND
#   ✓ company_name: '株式会社サンライズ物流' - FOUND
#   ✓ company_address: '〒135-8625 東京都江東区豊洲2-4-9 アーバンドック ららぽーと豊洲' - FOUND
#   ✓ phone_number: '03-6910-1235' - FOUND
#   → Found: 4/4 (100.0%)
#
# Evaluating: paddle_Redactor_sample_0028.txt
# Base name: Redactor_sample_0028
#   ✓ full_name: '後藤 美月' - FOUND
#   ✓ company_name: 'サクラ精密機器' - FOUND
#   ✗ company_address: '〒330-9555 埼玉県さいたま市大宮区桜木町1-7-5 ソニックシティビル' - NOT FOUND
#   ✓ phone_number: '048-647-4112' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0029.txt
# Base name: Redactor_sample_0029
#   ✗ full_name: '村上 颯太' - NOT FOUND
#   ✗ company_name: 'フロンティア・エージェンシー' - NOT FOUND
#   ✗ company_address: '〒150-0002 東京都渋谷区渋谷2-24-12 渋谷スクランブルスクエア' - NOT FOUND
#   ✓ phone_number: '03-4221-4280' - FOUND
#   → Found: 1/4 (25.0%)
#
# Evaluating: paddle_Redactor_sample_0030.txt
# Base name: Redactor_sample_0030
#   ✗ full_name: '長谷川 莉子' - NOT FOUND
#   ✓ company_name: '株式会社京葉エンジニアリング' - FOUND
#   ✗ company_address: '〒261-7132 千葉県千葉市美浜区中瀬2-6-1 WBGマリブウエスト' - NOT FOUND
#   ✗ phone_number: '043-297-3000' - NOT FOUND
#   → Found: 1/4 (25.0%)
#
# Evaluating: paddle_Redactor_sample_0031.txt
# Base name: Redactor_sample_0031
#   ✓ full_name: '西村 陽菜' - FOUND
#   ✗ company_name: 'フロンティア・エージェンシー' - NOT FOUND
#   ✗ company_address: '〒150-0002 東京都渋谷区渋谷2-24-12 渋谷スクランブルスクエア' - NOT FOUND
#   ✓ phone_number: '03-4221-4281' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0032.txt
# Base name: Redactor_sample_0032
#   ✓ full_name: '石井 涼介' - FOUND
#   ✓ company_name: '株式会社京葉エンジニアリング' - FOUND
#   ✗ company_address: '〒261-7132 千葉県千葉市美浜区中瀬2-6-1 WBGマリブウエスト' - NOT FOUND
#   ✓ phone_number: '043-297-3001' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0033.txt
# Base name: Redactor_sample_0033
#   ✓ full_name: '山口 智也' - FOUND
#   ✓ company_name: '株式会社デジタル・ウェイブ' - FOUND
#   ✗ company_address: '〒105-7333 東京都港区東新橋1-9-1 東京汐留ビルディング' - NOT FOUND
#   ✗ phone_number: '03-6252-3456' - NOT FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0034.txt
# Base name: Redactor_sample_0034
#   ✓ full_name: '宮崎 楓' - FOUND
#   ✓ company_name: 'アーバンリサーチ株式会社' - FOUND
#   ✗ company_address: '〒550-0015 大阪府大阪市西区南堀江1-14-26 中澤唐木ビル' - NOT FOUND
#   ✓ phone_number: '06-6536-2323' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0035.txt
# Base name: Redactor_sample_0035
#   ✓ full_name: '野口 和樹' - FOUND
#   ✓ company_name: '株式会社アイリス' - FOUND
#   ✗ company_address: '〒980-0021 宮城県仙台市青葉区中央1-2-3 仙台マークワン' - NOT FOUND
#   ✓ phone_number: '022-716-1111' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0036.txt
# Base name: Redactor_sample_0036
#   ✓ full_name: '大塚 さくら' - FOUND
#   ✓ company_name: '株式会社ネオ・コーポレーション' - FOUND
#   ✗ company_address: '〒060-0005 北海道札幌市中央区北5条西2-5 JRタワー' - NOT FOUND
#   ✓ phone_number: '011-209-5100' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0037.txt
# Base name: Redactor_sample_0037
#   ✓ full_name: '松田 竜也' - FOUND
#   ✓ company_name: '株式会社デジタル・ウェイブ' - FOUND
#   ✗ company_address: '〒105-7333 東京都港区東新橋1-9-1 東京汐留ビルディング' - NOT FOUND
#   ✓ phone_number: '03-6252-3457' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0038.txt
# Base name: Redactor_sample_0038
#   ✓ full_name: '小野 恵子' - FOUND
#   ✗ company_name: 'アーバンリサーチ株式会社' - NOT FOUND
#   ✗ company_address: '〒550-0015 大阪府大阪市西区南堀江1-14-26 中澤唐木ビル' - NOT FOUND
#   ✓ phone_number: '06-6536-2324' - FOUND
#   → Found: 2/4 (50.0%)
#
# Evaluating: paddle_Redactor_sample_0039.txt
# Base name: Redactor_sample_0039
#   ✓ full_name: '田村 亮' - FOUND
#   ✓ company_name: '株式会社アイリス' - FOUND
#   ✗ company_address: '〒980-0021 宮城県仙台市青葉区中央1-2-3 仙台マークワン' - NOT FOUND
#   ✓ phone_number: '022-716-1112' - FOUND
#   → Found: 3/4 (75.0%)
#
# Evaluating: paddle_Redactor_sample_0040.txt
# Base name: Redactor_sample_0040
#   ✓ full_name: '杉山 結菜' - FOUND
#   ✓ company_name: '株式会社ネオ・コーポレーション' - FOUND
#   ✗ company_address: '〒060-0005 北海道札幌市中央区北5条西2-5 JRタワー' - NOT FOUND
#   ✓ phone_number: '011-209-5101' - FOUND
#   → Found: 3/4 (75.0%)
#
#
# ================================================================================
# SUMMARY OF RESULTS:
# ================================================================================
#                            txt_file  found  total  percentage
# 0   paddle_Redactor_sample_0001.txt      3      4        75.0
# 1   paddle_Redactor_sample_0002.txt      2      4        50.0
# 2   paddle_Redactor_sample_0003.txt      3      4        75.0
# 3   paddle_Redactor_sample_0004.txt      2      4        50.0
# 4   paddle_Redactor_sample_0005.txt      3      4        75.0
# 5   paddle_Redactor_sample_0006.txt      2      4        50.0
# 6   paddle_Redactor_sample_0007.txt      3      4        75.0
# 7   paddle_Redactor_sample_0008.txt      3      4        75.0
# 8   paddle_Redactor_sample_0009.txt      3      4        75.0
# 9   paddle_Redactor_sample_0010.txt      3      4        75.0
# 10  paddle_Redactor_sample_0011.txt      4      4       100.0
# 11  paddle_Redactor_sample_0012.txt      3      4        75.0
# 12  paddle_Redactor_sample_0013.txt      4      4       100.0
# 13  paddle_Redactor_sample_0014.txt      3      4        75.0
# 14  paddle_Redactor_sample_0015.txt      4      4       100.0
# 15  paddle_Redactor_sample_0016.txt      3      4        75.0
# 16  paddle_Redactor_sample_0017.txt      3      4        75.0
# 17  paddle_Redactor_sample_0018.txt      3      4        75.0
# 18  paddle_Redactor_sample_0019.txt      2      4        50.0
# 19  paddle_Redactor_sample_0020.txt      2      4        50.0
# 20  paddle_Redactor_sample_0021.txt      2      4        50.0
# 21  paddle_Redactor_sample_0022.txt      3      4        75.0
# 22  paddle_Redactor_sample_0023.txt      2      4        50.0
# 23  paddle_Redactor_sample_0024.txt      3      4        75.0
# 24  paddle_Redactor_sample_0025.txt      4      4       100.0
# 25  paddle_Redactor_sample_0026.txt      3      4        75.0
# 26  paddle_Redactor_sample_0027.txt      4      4       100.0
# 27  paddle_Redactor_sample_0028.txt      3      4        75.0
# 28  paddle_Redactor_sample_0029.txt      1      4        25.0
# 29  paddle_Redactor_sample_0030.txt      1      4        25.0
# 30  paddle_Redactor_sample_0031.txt      2      4        50.0
# 31  paddle_Redactor_sample_0032.txt      3      4        75.0
# 32  paddle_Redactor_sample_0033.txt      2      4        50.0
# 33  paddle_Redactor_sample_0034.txt      3      4        75.0
# 34  paddle_Redactor_sample_0035.txt      3      4        75.0
# 35  paddle_Redactor_sample_0036.txt      3      4        75.0
# 36  paddle_Redactor_sample_0037.txt      3      4        75.0
# 37  paddle_Redactor_sample_0038.txt      2      4        50.0
# 38  paddle_Redactor_sample_0039.txt      3      4        75.0
# 39  paddle_Redactor_sample_0040.txt      3      4        75.0
#
# ================================================================================
# DETAILED RESULTS BY COLUMN:
# ================================================================================
#                            txt_file             base_name  found  total  \
# 0   paddle_Redactor_sample_0001.txt  Redactor_sample_0001      3      4
# 1   paddle_Redactor_sample_0002.txt  Redactor_sample_0002      2      4
# 2   paddle_Redactor_sample_0003.txt  Redactor_sample_0003      3      4
# 3   paddle_Redactor_sample_0004.txt  Redactor_sample_0004      2      4
# 4   paddle_Redactor_sample_0005.txt  Redactor_sample_0005      3      4
# 5   paddle_Redactor_sample_0006.txt  Redactor_sample_0006      2      4
# 6   paddle_Redactor_sample_0007.txt  Redactor_sample_0007      3      4
# 7   paddle_Redactor_sample_0008.txt  Redactor_sample_0008      3      4
# 8   paddle_Redactor_sample_0009.txt  Redactor_sample_0009      3      4
# 9   paddle_Redactor_sample_0010.txt  Redactor_sample_0010      3      4
# 10  paddle_Redactor_sample_0011.txt  Redactor_sample_0011      4      4
# 11  paddle_Redactor_sample_0012.txt  Redactor_sample_0012      3      4
# 12  paddle_Redactor_sample_0013.txt  Redactor_sample_0013      4      4
# 13  paddle_Redactor_sample_0014.txt  Redactor_sample_0014      3      4
# 14  paddle_Redactor_sample_0015.txt  Redactor_sample_0015      4      4
# 15  paddle_Redactor_sample_0016.txt  Redactor_sample_0016      3      4
# 16  paddle_Redactor_sample_0017.txt  Redactor_sample_0017      3      4
# 17  paddle_Redactor_sample_0018.txt  Redactor_sample_0018      3      4
# 18  paddle_Redactor_sample_0019.txt  Redactor_sample_0019      2      4
# 19  paddle_Redactor_sample_0020.txt  Redactor_sample_0020      2      4
# 20  paddle_Redactor_sample_0021.txt  Redactor_sample_0021      2      4
# 21  paddle_Redactor_sample_0022.txt  Redactor_sample_0022      3      4
# 22  paddle_Redactor_sample_0023.txt  Redactor_sample_0023      2      4
# 23  paddle_Redactor_sample_0024.txt  Redactor_sample_0024      3      4
# 24  paddle_Redactor_sample_0025.txt  Redactor_sample_0025      4      4
# 25  paddle_Redactor_sample_0026.txt  Redactor_sample_0026      3      4
# 26  paddle_Redactor_sample_0027.txt  Redactor_sample_0027      4      4
# 27  paddle_Redactor_sample_0028.txt  Redactor_sample_0028      3      4
# 28  paddle_Redactor_sample_0029.txt  Redactor_sample_0029      1      4
# 29  paddle_Redactor_sample_0030.txt  Redactor_sample_0030      1      4
# 30  paddle_Redactor_sample_0031.txt  Redactor_sample_0031      2      4
# 31  paddle_Redactor_sample_0032.txt  Redactor_sample_0032      3      4
# 32  paddle_Redactor_sample_0033.txt  Redactor_sample_0033      2      4
# 33  paddle_Redactor_sample_0034.txt  Redactor_sample_0034      3      4
# 34  paddle_Redactor_sample_0035.txt  Redactor_sample_0035      3      4
# 35  paddle_Redactor_sample_0036.txt  Redactor_sample_0036      3      4
# 36  paddle_Redactor_sample_0037.txt  Redactor_sample_0037      3      4
# 37  paddle_Redactor_sample_0038.txt  Redactor_sample_0038      2      4
# 38  paddle_Redactor_sample_0039.txt  Redactor_sample_0039      3      4
# 39  paddle_Redactor_sample_0040.txt  Redactor_sample_0040      3      4
#
#     percentage  full_name company_name company_address phone_number
# 0         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 1         50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 2         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 3         50.0  NOT FOUND        FOUND       NOT FOUND        FOUND
# 4         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 5         50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 6         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 7         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 8         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 9         75.0      FOUND        FOUND       NOT FOUND        FOUND
# 10       100.0      FOUND        FOUND           FOUND        FOUND
# 11        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 12       100.0      FOUND        FOUND           FOUND        FOUND
# 13        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 14       100.0      FOUND        FOUND           FOUND        FOUND
# 15        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 16        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 17        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 18        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 19        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 20        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 21        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 22        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 23        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 24       100.0      FOUND        FOUND           FOUND        FOUND
# 25        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 26       100.0      FOUND        FOUND           FOUND        FOUND
# 27        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 28        25.0  NOT FOUND    NOT FOUND       NOT FOUND        FOUND
# 29        25.0  NOT FOUND        FOUND       NOT FOUND    NOT FOUND
# 30        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 31        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 32        50.0      FOUND        FOUND       NOT FOUND    NOT FOUND
# 33        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 34        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 35        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 36        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 37        50.0      FOUND    NOT FOUND       NOT FOUND        FOUND
# 38        75.0      FOUND        FOUND       NOT FOUND        FOUND
# 39        75.0      FOUND        FOUND       NOT FOUND        FOUND
#
# Results saved to: ../data/ocr_evaluation_results.csv
